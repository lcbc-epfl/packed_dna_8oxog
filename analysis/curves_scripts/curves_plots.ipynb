# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams["font.family"] = "Times New Roman"

# %%
df_test1 = pd.read_csv('./wt_0_weka_inputs/sec1_wt_G_0_weka_input.csv')
df_test2 = pd.read_csv('./wt_0_weka_inputs/20_notails_wt_0_all_weka_input.csv')
#print(df_sec1)

# %%
test1_propel = df_test1.loc[:,'Propel']
test1_propel.hist(bins=30);
test2_propel = df_test2.loc[:,'Propel']
test2_propel.hist(bins=30)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()
plt.hist([test1_propel, test2_propel], 30, label=['test1', 'test2'], color=['blue','orange'])
plt.legend(loc='upper right')
ax.set_xlabel('Value (Degrees)')
ax.set_ylabel('Population')
ax.set_title('Propel Example')
plt.show()

# %%
df_wt_notails = pd.read_csv('./wt_0_weka_inputs/20_notails_wt_0_all_weka_input.csv')
df_r1_notails = pd.read_csv('./8oxoG_0_reg1_weka_inputs/20_no_tails_8oxo_0_G_weka_input.csv')
df_r2_notails = pd.read_csv('./8oxoG_0_reg2_weka_inputs/20_notails_8oxoG_0_reg2_weka_input.csv')

# %%
wt_notails_shear = df_wt_notails.loc[:,'Shear']
r1_notails_shear = df_r1_notails.loc[:,'Shear']
r2_notails_shear = df_r2_notails.loc[:,'Shear']

wt_notails_stretch = df_wt_notails.loc[:,'Stretch']
r1_notails_stretch = df_r1_notails.loc[:,'Stretch']
r2_notails_stretch = df_r2_notails.loc[:,'Stretch']

wt_notails_stagger = df_wt_notails.loc[:,'Stagger']
r1_notails_stagger = df_r1_notails.loc[:,'Stagger']
r2_notails_stagger = df_r2_notails.loc[:,'Stagger']

wt_notails_buckle = df_wt_notails.loc[:,'Buckle']
r1_notails_buckle = df_r1_notails.loc[:,'Buckle']
r2_notails_buckle = df_r2_notails.loc[:,'Buckle']

wt_notails_propeller = df_wt_notails.loc[:,'Propel']
r1_notails_propeller = df_r1_notails.loc[:,'Propel']
r2_notails_propeller = df_r2_notails.loc[:,'Propel']

wt_notails_opening = df_wt_notails.loc[:,'Opening']
r1_notails_opening = df_r1_notails.loc[:,'Opening']
r2_notails_opening = df_r2_notails.loc[:,'Opening']

# %%
a = round(wt_notails_shear.mean(),5)
b = round(wt_notails_shear.std(),5)
c = round(r1_notails_shear.mean(),5)
d = round(r1_notails_shear.std(),5)
e = round(r2_notails_shear.mean(),5)
f = round(r2_notails_shear.std(),5)
print("Shear Statistics")
print("The wt shear mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt shear mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 shear mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 shear mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))

print("The r2 shear mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 shear mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
# Out:
# Shear Statistics
# The wt shear mean and standard devation are -0.01652  +/-  0.03748
# The range of values within one standard deviation of the wt shear mean are from  -0.054  to  0.02096
# The r1 shear mean and standard devation are -0.00494  +/-  0.03335
# The range of values within one standard deviation of the r1 shear mean are from  -0.03829  to  0.02841
# The difference in mean value between wt and r1 is -0.01158
# The r2 shear mean and standard devation are -0.0045  +/-  0.03251
# The range of values within one standard deviation of the r2 shear mean are from  -0.03701  to  0.02801

# %%
a = round(wt_notails_stretch.mean(),5)
b = round(wt_notails_stretch.std(),5)
c = round(r1_notails_stretch.mean(),5)
d = round(r1_notails_stretch.std(),5)
e = round(r2_notails_stretch.mean(),5)
f = round(r2_notails_stretch.std(),5)
print("Stretch Statistics")
print("The wt stretch mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt stretch mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 stretch mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 stretch mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))

print("The r2 stretch mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 stretch mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Stretch Statistics
# The wt stretch mean and standard devation are 0.02353  +/-  0.01327
# The range of values within one standard deviation of the wt stretch mean are from  0.01026  to  0.0368
# The r1 stretch mean and standard devation are 0.02635  +/-  0.01368
# The range of values within one standard deviation of the r1 stretch mean are from  0.01267  to  0.04003
# The difference in mean value between wt and r1 is -0.00282
# The r2 stretch mean and standard devation are 0.03196  +/-  0.01434
# The range of values within one standard deviation of the r2 stretch mean are from  0.01762  to  0.0463
# The difference in mean value between wt and r2 is -0.00843

# %%
a = round(wt_notails_stagger.mean(),5)
b = round(wt_notails_stagger.std(),5)
c = round(r1_notails_stagger.mean(),5)
d = round(r1_notails_stagger.std(),5)
e = round(r2_notails_stagger.mean(),5)
f = round(r2_notails_stagger.std(),5)
print("Stagger Statistics")
print("The wt stagger mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt stagger mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 stagger mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 stagger mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 stagger mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 stagger mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Stagger Statistics
# The wt stagger mean and standard devation are 0.06229  +/-  0.04913
# The range of values within one standard deviation of the wt stagger mean are from  0.01316  to  0.11142
# The r1 stagger mean and standard devation are 0.04503  +/-  0.04858
# The range of values within one standard deviation of the r1 stagger mean are from  -0.00355  to  0.09361
# The difference in mean value between wt and r1 is 0.01726
# The r2 stagger mean and standard devation are 0.02792  +/-  0.04942
# The range of values within one standard deviation of the r2 stagger mean are from  -0.0215  to  0.07734
# The difference in mean value between wt and r2 is 0.03437

# %%
a = round(wt_notails_buckle.mean(),5)
b = round(wt_notails_buckle.std(),5)
c = round(r1_notails_buckle.mean(),5)
d = round(r1_notails_buckle.std(),5)
e = round(r2_notails_buckle.mean(),5)
f = round(r2_notails_buckle.std(),5)
print("Buckle Statistics")
print("The wt buckle mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt buckle mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 buckle mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 buckle mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))

print("The r2 buckle mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 buckle mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Buckle Statistics
# The wt buckle mean and standard devation are -0.24847  +/-  1.18142
# The range of values within one standard deviation of the wt buckle mean are from  -1.42989  to  0.93295
# The r1 buckle mean and standard devation are -0.92148  +/-  1.18643
# The range of values within one standard deviation of the r1 buckle mean are from  -2.10791  to  0.26495
# The difference in mean value between wt and r1 is 0.67301
# The r2 buckle mean and standard devation are -0.48136  +/-  1.21528
# The range of values within one standard deviation of the r2 buckle mean are from  -1.69664  to  0.73392
# The difference in mean value between wt and r2 is 0.23289

# %%
a = round(wt_notails_propeller.mean(),5)
b = round(wt_notails_propeller.std(),5)
c = round(r1_notails_propeller.mean(),5)
d = round(r1_notails_propeller.std(),5)
e = round(r2_notails_propeller.mean(),5)
f = round(r2_notails_propeller.std(),5)
print("Propeller Statistics")
print("The wt propeller mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt propeller mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 propeller mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 propeller mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 propeller mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 propeller mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-e,5)))
# Out:
# Propeller Statistics
# The wt propeller mean and standard devation are -9.35904  +/-  0.85842
# The range of values within one standard deviation of the wt propeller mean are from  -10.21746  to  -8.50062
# The r1 propeller mean and standard devation are -9.05565  +/-  0.81493
# The range of values within one standard deviation of the r1 propeller mean are from  -9.87058  to  -8.24072
# The difference in mean value between wt and r1 is -0.30339
# The r2 propeller mean and standard devation are -9.50558  +/-  0.77924
# The range of values within one standard deviation of the r2 propeller mean are from  -10.28482  to  -8.72634
# The difference in mean value between wt and r1 is 0.14654

# %%
a = round(wt_notails_opening.mean(),5)
b = round(wt_notails_opening.std(),5)
c = round(r1_notails_opening.mean(),5)
d = round(r1_notails_opening.std(),5)
e = round(r2_notails_opening.mean(),5)
f = round(r2_notails_opening.std(),5)
print("Opening Statistics")
print("The wt opening mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt opening mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 opening mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 opening mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 opening mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 opening mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Opening Statistics
# The wt opening mean and standard devation are 1.46193  +/-  0.49787
# The range of values within one standard deviation of the wt opening mean are from  0.96406  to  1.9598
# The r1 opening mean and standard devation are 1.30745  +/-  0.53064
# The range of values within one standard deviation of the r1 opening mean are from  0.77681  to  1.83809
# The difference in mean value between wt and r1 is 0.15448
# The r2 opening mean and standard devation are 1.18307  +/-  0.51247
# The range of values within one standard deviation of the r2 opening mean are from  0.6706  to  1.69554
# The difference in mean value between wt and r2 is 0.27886

# %%
fig, ((ax0, ax1),(ax2,ax3), (ax4,ax5)) = plt.subplots(nrows=3, ncols=2, figsize=(10,8))
bins_shear = np.linspace(-0.15, 0.15, 30)
ax0.hist([wt_notails_shear, r1_notails_shear], bins_shear, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Shear: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-0.15, 0.15)
ax0.set_ylim(0, 130)
ax1.hist([wt_notails_shear, r2_notails_shear], bins_shear, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Shear: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-0.15, 0.15)
ax1.set_ylim(0, 130)
bins_stretch = np.linspace(-0.025, 0.08, 30)
ax2.hist([wt_notails_stretch, r1_notails_stretch], bins_stretch, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Stretch: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-0.025, 0.08)
ax2.set_ylim(0, 130)
ax3.hist([wt_notails_stretch, r2_notails_stretch], bins_stretch, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Stretch: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-0.025, 0.08)
ax3.set_ylim(0, 130)
bins_stagger = np.linspace(-0.15, 0.25, 30)
ax4.hist([wt_notails_stagger, r1_notails_stagger], bins_stagger, label=['WT', 'Reg1'], color=['blue','red'])
ax4.legend(loc='upper right')
ax4.set_xlabel('Value ($\AA$)')
ax4.set_ylabel('Frame Count')
ax4.set_title('Stagger: Wild-Type vs Region 1 Defect ')
ax4.set_xlim(-0.15, 0.25)
ax4.set_ylim(0, 130)
ax5.hist([wt_notails_stagger, r2_notails_stagger], bins_stagger, label=['WT', 'Reg2'], color=['blue','orange'])
ax5.legend(loc='upper right')
ax5.set_xlabel('Value ($\AA$)')
ax5.set_ylabel('Frame Count')
ax5.set_title('Stagger: Wild-Type vs Region 2 Defect ')
ax5.set_xlim(-0.15, 0.25)
ax5.set_ylim(0, 130)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3), (ax4,ax5)) = plt.subplots(nrows=3, ncols=2, figsize=(10,8))
bins_buckle = np.linspace(-5, 5, 30)
ax0.hist([wt_notails_buckle, r1_notails_buckle], bins_buckle, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Buckle: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-5, 5)
ax0.set_ylim(0, 125)
ax1.hist([wt_notails_buckle, r2_notails_buckle], bins_buckle, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Buckle: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-5, 5)
ax1.set_ylim(0, 125)
bins_propeller = np.linspace(-12, -6, 30)
ax2.hist([wt_notails_propeller, r1_notails_propeller], bins_propeller, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Propeller: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-12, -6)
ax2.set_ylim(0, 125)
ax3.hist([wt_notails_propeller, r2_notails_propeller], bins_propeller, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Propeller: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-12, -6)
ax3.set_ylim(0, 125)
bins_opening = np.linspace(-1, 3, 30)
ax4.hist([wt_notails_opening, r1_notails_opening], bins_opening, label=['WT', 'Reg1'], color=['blue','red'])
ax4.legend(loc='upper right')
ax4.set_xlabel('Value ($^\circ$)')
ax4.set_ylabel('Frame Count')
ax4.set_title('Opening: Wild-Type vs Region 1 Defect ')
ax4.set_xlim(-1, 3)
ax4.set_ylim(0, 120)
ax5.hist([wt_notails_opening, r2_notails_opening], bins_opening, label=['WT', 'Reg2'], color=['blue','orange'])
ax5.legend(loc='upper right')
ax5.set_xlabel('Value ($^\circ$)')
ax5.set_ylabel('Frame Count')
ax5.set_title('Opening: Wild-Type vs Region 2 Defect ')
ax5.set_xlim(-1, 3)
ax5.set_ylim(0, 125)
fig.tight_layout()

# %%
wt_notails_shift = df_wt_notails.loc[:,'Shift']
r1_notails_shift = df_r1_notails.loc[:,'Shift']
r2_notails_shift = df_r2_notails.loc[:,'Shift']

wt_notails_slide = df_wt_notails.loc[:,'Slide']
r1_notails_slide = df_r1_notails.loc[:,'Slide']
r2_notails_slide = df_r2_notails.loc[:,'Slide']

wt_notails_rise = df_wt_notails.loc[:,'Rise']
r1_notails_rise = df_r1_notails.loc[:,'Rise']
r2_notails_rise = df_r2_notails.loc[:,'Rise']

wt_notails_tilt = df_wt_notails.loc[:,'Tilt']
r1_notails_tilt = df_r1_notails.loc[:,'Tilt']
r2_notails_tilt = df_r2_notails.loc[:,'Tilt']

wt_notails_roll = df_wt_notails.loc[:,'Roll']
r1_notails_roll = df_r1_notails.loc[:,'Roll']
r2_notails_roll = df_r2_notails.loc[:,'Roll']

wt_notails_twist = df_wt_notails.loc[:,'Twist']
r1_notails_twist = df_r1_notails.loc[:,'Twist']
r2_notails_twist = df_r2_notails.loc[:,'Twist']

# %%
a = round(wt_notails_shift.mean(),5)
b = round(wt_notails_shift.std(),5)
c = round(r1_notails_shift.mean(),5)
d = round(r1_notails_shift.std(),5)
e = round(r2_notails_shift.mean(),5)
f = round(r2_notails_shift.std(),5)
print("Shift Statistics")
print("The wt shift mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt shift mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 shift mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 shift mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 shift mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 shift mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Shift Statistics
# The wt shift mean and standard devation are -0.00894  +/-  0.03612
# The range of values within one standard deviation of the wt shift mean are from  -0.04506  to  0.02718
# The r1 shift mean and standard devation are 0.00505  +/-  0.04081
# The range of values within one standard deviation of the r1 shift mean are from  -0.03576  to  0.04586
# The difference in mean value between wt and r1 is -0.01399
# The r2 shift mean and standard devation are -0.00728  +/-  0.03876
# The range of values within one standard deviation of the r2 shift mean are from  -0.04604  to  0.03148
# The difference in mean value between wt and r2 is -0.00166

# %%
a = round(wt_notails_slide.mean(),5)
b = round(wt_notails_slide.std(),5)
c = round(r1_notails_slide.mean(),5)
d = round(r1_notails_slide.std(),5)
e = round(r2_notails_slide.mean(),5)
f = round(r2_notails_slide.std(),5)
print("Slide Statistics")
print("The wt slide mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt slide mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 slide mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 slide mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 slide mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 slide mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Slide Statistics
# The wt slide mean and standard devation are -0.25439  +/-  0.04784
# The range of values within one standard deviation of the wt slide mean are from  -0.30223  to  -0.20655
# The r1 slide mean and standard devation are -0.2549  +/-  0.04833
# The range of values within one standard deviation of the r1 slide mean are from  -0.30323  to  -0.20657
# The difference in mean value between wt and r1 is 0.00051
# The r2 slide mean and standard devation are -0.24635  +/-  0.05262
# The range of values within one standard deviation of the r2 slide mean are from  -0.29897  to  -0.19373
# The difference in mean value between wt and r2 is -0.00804

# %%
a = round(wt_notails_rise.mean(),5)
b = round(wt_notails_rise.std(),5)
c = round(r1_notails_rise.mean(),5)
d = round(r1_notails_rise.std(),5)
e = round(r2_notails_rise.mean(),5)
f = round(r2_notails_rise.std(),5)
print("Rise Statistics")
print("The wt rise mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt rise mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 rise mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 rise mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 rise mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 rise mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Rise Statistics
# The wt rise mean and standard devation are 3.38742  +/-  0.0107
# The range of values within one standard deviation of the wt rise mean are from  3.37672  to  3.39812
# The r1 rise mean and standard devation are 3.38477  +/-  0.01211
# The range of values within one standard deviation of the r1 rise mean are from  3.37266  to  3.39688
# The difference in mean value between wt and r1 is 0.00265
# The r2 rise mean and standard devation are 3.38764  +/-  0.01261
# The range of values within one standard deviation of the r2 rise mean are from  3.37503  to  3.40025
# The difference in mean value between wt and r2 is -0.00022

# %%
a = round(wt_notails_tilt.mean(),5)
b = round(wt_notails_tilt.std(),5)
c = round(r1_notails_tilt.mean(),5)
d = round(r1_notails_tilt.std(),5)
e = round(r2_notails_tilt.mean(),5)
f = round(r2_notails_tilt.std(),5)
print("Tilt Statistics")
print("The wt rise mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt tilt mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 rise mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 tilt mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 rise mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 tilt mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Tilt Statistics
# The wt rise mean and standard devation are 0.01361  +/-  0.2473
# The range of values within one standard deviation of the wt tilt mean are from  -0.23369  to  0.26091
# The r1 rise mean and standard devation are 0.03118  +/-  0.26643
# The range of values within one standard deviation of the r1 tilt mean are from  -0.23525  to  0.29761
# The difference in mean value between wt and r1 is -0.01757
# The r2 rise mean and standard devation are 0.03333  +/-  0.26084
# The range of values within one standard deviation of the r2 tilt mean are from  -0.22751  to  0.29417
# The difference in mean value between wt and r2 is -0.01972

# %%
a = round(wt_notails_roll.mean(),5)
b = round(wt_notails_roll.std(),5)
c = round(r1_notails_roll.mean(),5)
d = round(r1_notails_roll.std(),5)
e = round(r2_notails_roll.mean(),5)
f = round(r2_notails_roll.std(),5)
print("Roll Statistics")
print("The wt roll mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt roll mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 roll mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 roll mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 roll mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 roll mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Roll Statistics
# The wt roll mean and standard devation are -0.27021  +/-  0.3536
# The range of values within one standard deviation of the wt roll mean are from  -0.62381  to  0.08339
# The r1 roll mean and standard devation are -0.25875  +/-  0.40021
# The range of values within one standard deviation of the r1 roll mean are from  -0.65896  to  0.14146
# The difference in mean value between wt and r1 is -0.01146
# The r2 roll mean and standard devation are -0.05499  +/-  0.3771
# The range of values within one standard deviation of the r2 roll mean are from  -0.43209  to  0.32211
# The difference in mean value between wt and r2 is -0.21522

# %%
a = round(wt_notails_twist.mean(),5)
b = round(wt_notails_twist.std(),5)
c = round(r1_notails_twist.mean(),5)
d = round(r1_notails_twist.std(),5)
e = round(r2_notails_twist.mean(),5)
f = round(r2_notails_twist.std(),5)
print("Twist Statistics")
print("The wt twist mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt twist mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 twist mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 twist mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 twist mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 twist mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Twist Statistics
# The wt twist mean and standard devation are 34.46523  +/-  0.09951
# The range of values within one standard deviation of the wt twist mean are from  34.36572  to  34.56474
# The r1 twist mean and standard devation are 34.4384  +/-  0.13282
# The range of values within one standard deviation of the r1 twist mean are from  34.30558  to  34.57122
# The difference in mean value between wt and r1 is 0.02683
# The r2 twist mean and standard devation are 34.63118  +/-  0.11933
# The range of values within one standard deviation of the r2 twist mean are from  34.51185  to  34.75051
# The difference in mean value between wt and r2 is -0.16595

# %%
fig, ((ax0, ax1),(ax2,ax3), (ax4,ax5)) = plt.subplots(nrows=3, ncols=2, figsize=(10,8))
bins_shift = np.linspace(-0.15, 0.15, 30)
ax0.hist([wt_notails_shift, r1_notails_shift], bins_shift, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Shift: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-0.15, 0.15)
ax0.set_ylim(0, 130)
ax1.hist([wt_notails_shift, r2_notails_shift], bins_shift, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Shift: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-0.15, 0.15)
ax1.set_ylim(0, 125)
bins_slide = np.linspace(-0.45, -0.05, 30)
ax2.hist([wt_notails_slide, r1_notails_slide], bins_slide, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Slide: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-0.45, -0.05)
ax2.set_ylim(0, 130)
ax3.hist([wt_notails_slide, r2_notails_slide], bins_slide, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Slide: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-0.45, -0.05)
ax3.set_ylim(0, 130)
bins_rise = np.linspace(3.34, 3.43, 30)
ax4.hist([wt_notails_rise, r1_notails_rise], bins_rise, label=['WT', 'Reg1'], color=['blue','red'])
ax4.legend(loc='upper right')
ax4.set_xlabel('Value ($\AA$)')
ax4.set_ylabel('Frame Count')
ax4.set_title('Rise: Wild-Type vs Region 1 Defect ')
ax4.set_xlim(3.34, 3.43)
ax4.set_ylim(0, 130)
ax5.hist([wt_notails_rise, r2_notails_rise], bins_rise, label=['WT', 'Reg2'], color=['blue','orange'])
ax5.legend(loc='upper right')
ax5.set_xlabel('Value ($\AA$)')
ax5.set_ylabel('Frame Count')
ax5.set_title('Rise: Wild-Type vs Region 2 Defect ')
ax5.set_xlim(3.34, 3.43)
ax5.set_ylim(0, 130)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3), (ax4,ax5)) = plt.subplots(nrows=3, ncols=2, figsize=(10,8))
bins_tilt = np.linspace(-1, 1, 30)
ax0.hist([wt_notails_tilt, r1_notails_tilt], bins_tilt, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Tilt: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-1, 1)
ax0.set_ylim(0, 150)
ax1.hist([wt_notails_tilt, r2_notails_tilt], bins_tilt, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Tilt: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-1, 1)
ax1.set_ylim(0, 150)
bins_roll = np.linspace(-1.5, 1.5, 30)
ax2.hist([wt_notails_roll, r1_notails_roll], bins_roll, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Roll: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-1.5, 1.5)
ax2.set_ylim(0, 150)
ax3.hist([wt_notails_roll,r2_notails_roll], bins_roll, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Roll: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-1.5, 1.5)
ax3.set_ylim(0, 150)
bins_twist = np.linspace(34, 35, 30)
ax4.hist([wt_notails_twist, r1_notails_twist], bins_twist, label=['WT', 'Reg1'], color=['blue','red'])
ax4.legend(loc='upper right')
ax4.set_xlabel('Value ($^\circ$)')
ax4.set_ylabel('Frame Count')
ax4.set_title('Twist: Wild-Type vs Region 1 Defect ')
ax4.set_xlim(34, 35)
ax4.set_ylim(0, 150)
ax5.hist([wt_notails_twist, r2_notails_twist], bins_twist, label=['WT', 'Reg2'], color=['blue','orange'])
ax5.legend(loc='upper right')
ax5.set_xlabel('Value ($^\circ$)')
ax5.set_ylabel('Frame Count')
ax5.set_title('Twist: Wild-Type vs Region 2 Defect ')
ax5.set_xlim(34, 35)
ax5.set_ylim(0, 150)
fig.tight_layout()

# %%
wt_notails_xdisp = df_wt_notails.loc[:,'Xdisp']
r1_notails_xdisp = df_r1_notails.loc[:,'Xdisp']
r2_notails_xdisp = df_r2_notails.loc[:,'Xdisp']

wt_notails_ydisp = df_wt_notails.loc[:,'Ydisp']
r1_notails_ydisp = df_r1_notails.loc[:,'Ydisp']
r2_notails_ydisp = df_r2_notails.loc[:,'Ydisp']

wt_notails_inclin = df_wt_notails.loc[:,'Inclin']
r1_notails_inclin = df_r1_notails.loc[:,'Inclin']
r2_notails_inclin = df_r2_notails.loc[:,'Inclin']

wt_notails_tip = df_wt_notails.loc[:,'Tip']
r1_notails_tip = df_r1_notails.loc[:,'Tip']
r2_notails_tip = df_r2_notails.loc[:,'Tip']

# %%
a = round(wt_notails_xdisp.mean(),5)
b = round(wt_notails_xdisp.std(),5)
c = round(r1_notails_xdisp.mean(),5)
d = round(r1_notails_xdisp.std(),5)
e = round(r2_notails_xdisp.mean(),5)
f = round(r2_notails_xdisp.std(),5)
print("X-Displacement Statistics")
print("The wt xdisp mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt xdisp mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 xdisp mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 xdisp mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 xdisp mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 xdisp mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# X-Displacement Statistics
# The wt xdisp mean and standard devation are -0.41011  +/-  0.05925
# The range of values within one standard deviation of the wt xdisp mean are from  -0.46936  to  -0.35086
# The r1 xdisp mean and standard devation are -0.44365  +/-  0.0644
# The range of values within one standard deviation of the r1 xdisp mean are from  -0.50805  to  -0.37925
# The difference in mean value between wt and r1 is 0.03354
# The r2 xdisp mean and standard devation are -0.47968  +/-  0.06641
# The range of values within one standard deviation of the r2 xdisp mean are from  -0.54609  to  -0.41327
# The difference in mean value between wt and r2 is 0.06957

# %%
a = round(wt_notails_ydisp.mean(),5)
b = round(wt_notails_ydisp.std(),5)
c = round(r1_notails_ydisp.mean(),5)
d = round(r1_notails_ydisp.std(),5)
e = round(r2_notails_ydisp.mean(),5)
f = round(r2_notails_ydisp.std(),5)
print("Y-Displacement Statistics")
print("The wt ydisp mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt ydisp mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 ydisp mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 ydisp mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 ydisp mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 ydisp mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Y-Displacement Statistics
# The wt ydisp mean and standard devation are 0.01437  +/-  0.04564
# The range of values within one standard deviation of the wt ydisp mean are from  -0.03127  to  0.06001
# The r1 ydisp mean and standard devation are -0.00624  +/-  0.05056
# The range of values within one standard deviation of the r1 ydisp mean are from  -0.0568  to  0.04432
# The difference in mean value between wt and r1 is 0.02061
# The r2 ydisp mean and standard devation are 0.0149  +/-  0.04993
# The range of values within one standard deviation of the r2 ydisp mean are from  -0.03503  to  0.06483
# The difference in mean value between wt and r2 is -0.00053

# %%
a = round(wt_notails_inclin.mean(),5)
b = round(wt_notails_inclin.std(),5)
c = round(r1_notails_inclin.mean(),5)
d = round(r1_notails_inclin.std(),5)
e = round(r2_notails_inclin.mean(),5)
f = round(r2_notails_inclin.std(),5)
print("Inclination Statistics")
print("The wt inclin mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt inclin mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 inclin mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 inclin mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 inclin mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 inclin mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Inclination Statistics
# The wt inclin mean and standard devation are -0.21735  +/-  0.57674
# The range of values within one standard deviation of the wt inclin mean are from  -0.79409  to  0.35939
# The r1 inclin mean and standard devation are -0.12056  +/-  0.65591
# The range of values within one standard deviation of the r1 inclin mean are from  -0.77647  to  0.53535
# The difference in mean value between wt and r1 is -0.09679
# The r2 inclin mean and standard devation are 0.26824  +/-  0.61762
# The range of values within one standard deviation of the r2 inclin mean are from  -0.34938  to  0.88586
# The difference in mean value between wt and r2 is -0.48559

# %%
a = round(wt_notails_tip.mean(),5)
b = round(wt_notails_tip.std(),5)
c = round(r1_notails_tip.mean(),5)
d = round(r1_notails_tip.std(),5)
e = round(r2_notails_tip.mean(),5)
f = round(r2_notails_tip.std(),5)
print("Tip Statistics")
print("The wt inclin mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt tip mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 tip mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 tip mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 tip mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 tip mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Tip Statistics
# The wt inclin mean and standard devation are -0.06326  +/-  0.40441
# The range of values within one standard deviation of the wt tip mean are from  -0.46767  to  0.34115
# The r1 tip mean and standard devation are -0.05729  +/-  0.44238
# The range of values within one standard deviation of the r1 tip mean are from  -0.49967  to  0.38509
# The difference in mean value between wt and r1 is -0.00597
# The r2 tip mean and standard devation are -0.11579  +/-  0.42983
# The range of values within one standard deviation of the r2 tip mean are from  -0.54562  to  0.31404
# The difference in mean value between wt and r2 is 0.05253

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_xdisp = np.linspace(-0.7, -0.1, 30)
ax0.hist([wt_notails_xdisp, r1_notails_xdisp], bins_xdisp, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('X-Disp: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-0.7, -0.1)
ax0.set_ylim(0, 150)
ax1.hist([wt_notails_xdisp, r2_notails_xdisp], bins_xdisp, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('X-Disp: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-0.7, -0.1)
ax1.set_ylim(0, 150)
bins_ydisp = np.linspace(-0.2, 0.2, 30)
ax2.hist([wt_notails_ydisp, r1_notails_ydisp], bins_ydisp, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Y-Disp: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-0.2, 0.2)
ax2.set_ylim(0, 150)
ax3.hist([wt_notails_ydisp, r2_notails_ydisp], bins_ydisp, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Y-Disp: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-0.2, 0.2)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_inclin = np.linspace(-2.5, 2.5, 30)
ax0.hist([wt_notails_inclin, r1_notails_inclin], bins_inclin, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Inclination: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-2.5, 2.5)
ax0.set_ylim(0, 140)
ax1.hist([wt_notails_inclin, r2_notails_inclin], bins_inclin, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Inclincation: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-2.5, 2.5)
ax1.set_ylim(0, 140)
bins_tip = np.linspace(-2, 2, 30)
ax2.hist([wt_notails_tip, r1_notails_tip], bins_tip, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Tip: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-2, 2)
ax2.set_ylim(0, 140)
ax3.hist([wt_notails_tip, r2_notails_tip], bins_tip, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Tip: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-2, 2)
ax3.set_ylim(0, 140)
fig.tight_layout()

# %%
wt_notails_a1 = df_wt_notails.loc[:,'Alpha_1']
r1_notails_a1 = df_r1_notails.loc[:,'Alpha_1']
r2_notails_a1 = df_r2_notails.loc[:,'Alpha_1']

wt_notails_a2 = df_wt_notails.loc[:,'Alpha_2']
r1_notails_a2 = df_r1_notails.loc[:,'Alpha_2']
r2_notails_a2 = df_r2_notails.loc[:,'Alpha_2']

wt_notails_b1 = df_wt_notails.loc[:,'Beta_1']
r1_notails_b1 = df_r1_notails.loc[:,'Beta_1']
r2_notails_b1 = df_r2_notails.loc[:,'Beta_1']

wt_notails_b2= df_wt_notails.loc[:,'Beta_2']
r1_notails_b2 = df_r1_notails.loc[:,'Beta_2']
r2_notails_b2 = df_r2_notails.loc[:,'Beta_2']

# %%
a = round(wt_notails_a1.mean(),5)
b = round(wt_notails_a1.std(),5)
c = round(r1_notails_a1.mean(),5)
d = round(r1_notails_a1.std(),5)
e = round(r2_notails_a1.mean(),5)
f = round(r2_notails_a1.std(),5)
print("Alpha Strand 1 Statistics")
print("The wt a1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt a1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 a1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 a1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 a1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 a1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Alpha Strand 1 Statistics
# The wt a1 mean and standard devation are -69.57337  +/-  2.25209
# The range of values within one standard deviation of the wt a1 mean are from  -71.82546  to  -67.32128
# The r1 a1 mean and standard devation are -69.31656  +/-  2.39768
# The range of values within one standard deviation of the r1 a1 mean are from  -71.71424  to  -66.91888
# The difference in mean value between wt and r1 is -0.25681
# The r2 a1 mean and standard devation are -69.90899  +/-  2.04764
# The range of values within one standard deviation of the r2 a1 mean are from  -71.95663  to  -67.86135
# The difference in mean value between wt and r2 is 0.33562

# %%
a = round(wt_notails_a2.mean(),5)
b = round(wt_notails_a2.std(),5)
c = round(r1_notails_a2.mean(),5)
d = round(r1_notails_a2.std(),5)
e = round(r2_notails_a2.mean(),5)
f = round(r2_notails_a2.std(),5)
print("Alpha Strand 2 Statistics")
print("The wt a2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt a2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 a2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 a2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 a2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 a2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Alpha Strand 2 Statistics
# The wt a2 mean and standard devation are -72.02125  +/-  2.14373
# The range of values within one standard deviation of the wt a2 mean are from  -74.16498  to  -69.87752
# The r1 a2 mean and standard devation are -70.23672  +/-  2.22346
# The range of values within one standard deviation of the r1 a2 mean are from  -72.46018  to  -68.01326
# The difference in mean value between wt and r1 is -1.78453
# The r2 a2 mean and standard devation are -71.4802  +/-  2.09085
# The range of values within one standard deviation of the r2 a2 mean are from  -73.57105  to  -69.38935
# The difference in mean value between wt and r2 is -0.54105

# %%
a = round(wt_notails_b1.mean(),5)
b = round(wt_notails_b1.std(),5)
c = round(r1_notails_b1.mean(),5)
d = round(r1_notails_b1.std(),5)
e = round(r2_notails_b1.mean(),5)
f = round(r2_notails_b1.std(),5)
print("Beta Strand 1 Statistics")
print("The wt b1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt b1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 b1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 b1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 b1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 b1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Beta Strand 1 Statistics
# The wt b1 mean and standard devation are 76.64615  +/-  12.91549
# The range of values within one standard deviation of the wt b1 mean are from  63.73066  to  89.56164
# The r1 b1 mean and standard devation are 74.34881  +/-  12.42382
# The range of values within one standard deviation of the r1 b1 mean are from  61.92499  to  86.77263
# The difference in mean value between wt and r1 is 2.29734
# The r2 b1 mean and standard devation are 80.44639  +/-  12.83174
# The range of values within one standard deviation of the r2 b1 mean are from  67.61465  to  93.27813
# The difference in mean value between wt and r2 is -3.80024

# %%
a = round(wt_notails_b2.mean(),5)
b = round(wt_notails_b2.std(),5)
c = round(r1_notails_b2.mean(),5)
d = round(r1_notails_b2.std(),5)
e = round(r2_notails_b2.mean(),5)
f = round(r2_notails_b2.std(),5)
print("Beta Strand 2 Statistics")
print("The wt b2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt b2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 b2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 b2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 b2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 b2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Beta Strand 2 Statistics
# The wt b2 mean and standard devation are 79.65539  +/-  12.49542
# The range of values within one standard deviation of the wt b2 mean are from  67.15997  to  92.15081
# The r1 b2 mean and standard devation are 78.49202  +/-  13.30519
# The range of values within one standard deviation of the r1 b2 mean are from  65.18683  to  91.79721
# The difference in mean value between wt and r1 is 1.16337
# The r2 b2 mean and standard devation are 76.70139  +/-  12.74787
# The range of values within one standard deviation of the r2 b2 mean are from  63.95352  to  89.44926
# The difference in mean value between wt and r2 is 2.954

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_a = np.linspace(-80,-60, 30)
ax0.hist([wt_notails_a1, r1_notails_a1], bins_a, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Alpha 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-80, -60)
ax0.set_ylim(0, 160)
ax1.hist([wt_notails_a1, r2_notails_a1], bins_a, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Alpha 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-80, -60)
ax1.set_ylim(0, 160)
ax2.hist([wt_notails_a2, r1_notails_a2], bins_a, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Alpha 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-80, -60)
ax2.set_ylim(0, 160)
ax3.hist([wt_notails_a2, r2_notails_a2], bins_a, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Alpha 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-80, -60)
ax3.set_ylim(0, 160)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_b = np.linspace(30, 120, 30)
ax0.hist([wt_notails_b1, r1_notails_b1], bins_b, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Beta 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(30, 120)
ax0.set_ylim(0, 120)
ax1.hist([wt_notails_b1, r2_notails_b1], bins_b, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Beta 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(30, 120)
ax1.set_ylim(0, 120)
ax2.hist([wt_notails_b2, r1_notails_b2], bins_b, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Beta 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(30, 120)
ax2.set_ylim(0, 120)
ax3.hist([wt_notails_b2, r2_notails_b2], bins_b, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Beta 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(30, 120)
ax3.set_ylim(0, 120)
fig.tight_layout()

# %%
wt_notails_g1 = df_wt_notails.loc[:,'Gamma_1']
r1_notails_g1 = df_r1_notails.loc[:,'Gamma_1']
r2_notails_g1 = df_r2_notails.loc[:,'Gamma_1']

wt_notails_g2 = df_wt_notails.loc[:,'Gamma_2']
r1_notails_g2 = df_r1_notails.loc[:,'Gamma_2']
r2_notails_g2 = df_r2_notails.loc[:,'Gamma_2']

wt_notails_d1 = df_wt_notails.loc[:,'Delta_1']
r1_notails_d1 = df_r1_notails.loc[:,'Delta_1']
r2_notails_d1 = df_r2_notails.loc[:,'Delta_1']

wt_notails_d2 = df_wt_notails.loc[:,'Delta_2']
r1_notails_d2 = df_r1_notails.loc[:,'Delta_2']
r2_notails_d2 = df_r2_notails.loc[:,'Delta_2']

# %%
a = round(wt_notails_g1.mean(),5)
b = round(wt_notails_g1.std(),5)
c = round(r1_notails_g1.mean(),5)
d = round(r1_notails_g1.std(),5)
e = round(r2_notails_g1.mean(),5)
f = round(r2_notails_g1.std(),5)
print("Gamma Strand 1 Statistics")
print("The wt g1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt g1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 g1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 g1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 g1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 g1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Gamma Strand 1 Statistics
# The wt g1 mean and standard devation are 53.33276  +/-  3.72395
# The range of values within one standard deviation of the wt g1 mean are from  49.60881  to  57.05671
# The r1 g1 mean and standard devation are 50.7728  +/-  4.62356
# The range of values within one standard deviation of the r1 g1 mean are from  46.14924  to  55.39636
# The difference in mean value between wt and r1 is 2.55996
# The r2 g1 mean and standard devation are 54.86902  +/-  2.54492
# The range of values within one standard deviation of the r2 g1 mean are from  52.3241  to  57.41394
# The difference in mean value between wt and r2 is -1.53626

# %%
a = round(wt_notails_g2.mean(),5)
b = round(wt_notails_g2.std(),5)
c = round(r1_notails_g2.mean(),5)
d = round(r1_notails_g2.std(),5)
e = round(r2_notails_g2.mean(),5)
f = round(r2_notails_g2.std(),5)
print("Gamma Strand 2 Statistics")
print("The wt g2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt g2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 g2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 g2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 g2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 g2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Gamma Strand 2 Statistics
# The wt g2 mean and standard devation are 51.10578  +/-  4.03428
# The range of values within one standard deviation of the wt g2 mean are from  47.0715  to  55.14006
# The r1 g2 mean and standard devation are 52.0893  +/-  3.62006
# The range of values within one standard deviation of the r1 g2 mean are from  48.46924  to  55.70936
# The difference in mean value between wt and r1 is -0.98352
# The r2 g2 mean and standard devation are 53.48207  +/-  3.23218
# The range of values within one standard deviation of the r2 g2 mean are from  50.24989  to  56.71425
# The difference in mean value between wt and r2 is -2.37629

# %%
a = round(wt_notails_d1.mean(),5)
b = round(wt_notails_d1.std(),5)
c = round(r1_notails_d1.mean(),5)
d = round(r1_notails_d1.std(),5)
e = round(r2_notails_d1.mean(),5)
f = round(r2_notails_d1.std(),5)
print("Delta Strand 1 Statistics")
print("The wt g1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt d1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 d1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 d1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 d1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 d1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Delta Strand 1 Statistics
# The wt g1 mean and standard devation are 135.51546  +/-  1.18519
# The range of values within one standard deviation of the wt d1 mean are from  134.33027  to  136.70065
# The r1 d1 mean and standard devation are 136.1571  +/-  1.36073
# The range of values within one standard deviation of the r1 d1 mean are from  134.79637  to  137.51783
# The difference in mean value between wt and r1 is -0.64164
# The r2 d1 mean and standard devation are 133.08277  +/-  1.3399
# The range of values within one standard deviation of the r2 d1 mean are from  131.74287  to  134.42267
# The difference in mean value between wt and r2 is 2.43269

# %%
a = round(wt_notails_d2.mean(),5)
b = round(wt_notails_d2.std(),5)
c = round(r1_notails_d2.mean(),5)
d = round(r1_notails_d2.std(),5)
e = round(r2_notails_d2.mean(),5)
f = round(r2_notails_d2.std(),5)
print("Delta Strand 2 Statistics")
print("The wt d2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt d2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 d2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 d2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 d2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 d2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Delta Strand 2 Statistics
# The wt d2 mean and standard devation are 136.04977  +/-  1.21181
# The range of values within one standard deviation of the wt d2 mean are from  134.83796  to  137.26158
# The r1 d2 mean and standard devation are 135.87201  +/-  1.29345
# The range of values within one standard deviation of the r1 d2 mean are from  134.57856  to  137.16546
# The difference in mean value between wt and r1 is 0.17776
# The r2 d2 mean and standard devation are 134.02195  +/-  1.31806
# The range of values within one standard deviation of the r2 d2 mean are from  132.70389  to  135.34001
# The difference in mean value between wt and r2 is 2.02782

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_g = np.linspace(35, 67, 30)
ax0.hist([wt_notails_g1, r1_notails_g1], bins_g, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Gamma 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(35, 67)
ax0.set_ylim(0, 185)
ax1.hist([wt_notails_g1, r2_notails_g1], bins_g, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Gamma 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(35, 67)
ax1.set_ylim(0, 185)
ax2.hist([wt_notails_g2, r1_notails_g2], bins_g, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Gamma 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(35, 67)
ax2.set_ylim(0, 185)
ax3.hist([wt_notails_g2, r2_notails_g2], bins_g, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Gamma 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(35, 67)
ax3.set_ylim(0, 185)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_d = np.linspace(128, 142, 30)
ax0.hist([wt_notails_d1, r1_notails_d1], bins_d, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Delta 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(128, 142)
ax0.set_ylim(0, 170)
ax1.hist([wt_notails_d1, r2_notails_d1], bins_d, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Delta 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(128, 142)
ax1.set_ylim(0, 170)
ax2.hist([wt_notails_d2, r1_notails_d2], bins_d, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Delta 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(128, 142)
ax2.set_ylim(0, 170)
ax3.hist([wt_notails_d2, r2_notails_d2], bins_d, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Delta 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(128, 142)
ax3.set_ylim(0, 170)
fig.tight_layout()

# %%
wt_notails_e1 = df_wt_notails.loc[:,'Epsilon_1']
r1_notails_e1 = df_r1_notails.loc[:,'Epsilon_1']
r2_notails_e1 = df_r2_notails.loc[:,'Epsilon_1']

wt_notails_e2 = df_wt_notails.loc[:,'Epsilon_2']
r1_notails_e2 = df_r1_notails.loc[:,'Epsilon_2']
r2_notails_e2 = df_r2_notails.loc[:,'Epsilon_2']

wt_notails_z1 = df_wt_notails.loc[:,'Zeta_1']
r1_notails_z1 = df_r1_notails.loc[:,'Zeta_1']
r2_notails_z1 = df_r2_notails.loc[:,'Zeta_1']

wt_notails_z2 = df_wt_notails.loc[:,'Zeta_2']
r1_notails_z2 = df_r1_notails.loc[:,'Zeta_2']
r2_notails_z2 = df_r2_notails.loc[:,'Zeta_2']

# %%
a = round(wt_notails_e1.mean(),5)
b = round(wt_notails_e1.std(),5)
c = round(r1_notails_e1.mean(),5)
d = round(r1_notails_e1.std(),5)
e = round(r2_notails_e1.mean(),5)
f = round(r2_notails_e1.std(),5)
print("Epsilon Strand 1 Statistics")
print("The wt e1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt e1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 e1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 e1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 e1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 e1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Epsilon Strand 1 Statistics
# The wt e1 mean and standard devation are -91.9377  +/-  11.75178
# The range of values within one standard deviation of the wt e1 mean are from  -103.68948  to  -80.18592
# The r1 e1 mean and standard devation are -95.55858  +/-  11.39886
# The range of values within one standard deviation of the r1 e1 mean are from  -106.95744  to  -84.15972
# The difference in mean value between wt and r1 is 3.62088
# The r2 e1 mean and standard devation are -85.96136  +/-  11.91206
# The range of values within one standard deviation of the r2 e1 mean are from  -97.87342  to  -74.0493
# The difference in mean value between wt and r2 is -5.97634

# %%
a = round(wt_notails_e2.mean(),5)
b = round(wt_notails_e2.std(),5)
c = round(r1_notails_e2.mean(),5)
d = round(r1_notails_e2.std(),5)
e = round(r2_notails_e2.mean(),5)
f = round(r2_notails_e2.std(),5)
print("Epsilon Strand 2 Statistics")
print("The wt e2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt e2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 e2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 e2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 e2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 e2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Epsilon Strand 2 Statistics
# The wt e2 mean and standard devation are -95.95522  +/-  11.57105
# The range of values within one standard deviation of the wt e2 mean are from  -107.52627  to  -84.38417
# The r1 e2 mean and standard devation are -91.5803  +/-  12.20911
# The range of values within one standard deviation of the r1 e2 mean are from  -103.78941  to  -79.37119
# The difference in mean value between wt and r1 is -4.37492
# The r2 e2 mean and standard devation are -87.54143  +/-  11.80088
# The range of values within one standard deviation of the r2 e2 mean are from  -99.34231  to  -75.74055
# The difference in mean value between wt and r2 is -8.41379

# %%
a = round(wt_notails_z1.mean(),5)
b = round(wt_notails_z1.std(),5)
c = round(r1_notails_z1.mean(),5)
d = round(r1_notails_z1.std(),5)
e = round(r2_notails_z1.mean(),5)
f = round(r2_notails_z1.std(),5)
print("Zeta Strand 1 Statistics")
print("The wt z1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt z1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 z1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 z1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 z1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 z1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Zeta Strand 1 Statistics
# The wt z1 mean and standard devation are -52.59563  +/-  6.38394
# The range of values within one standard deviation of the wt z1 mean are from  -58.97957  to  -46.21169
# The r1 z1 mean and standard devation are -55.10301  +/-  7.2619
# The range of values within one standard deviation of the r1 z1 mean are from  -62.36491  to  -47.84111
# The difference in mean value between wt and r1 is 2.50738
# The r2 z1 mean and standard devation are -55.85899  +/-  6.77442
# The range of values within one standard deviation of the r2 z1 mean are from  -62.63341  to  -49.08457
# The difference in mean value between wt and r2 is 3.26336

# %%
a = round(wt_notails_z2.mean(),5)
b = round(wt_notails_z2.std(),5)
c = round(r1_notails_z2.mean(),5)
d = round(r1_notails_z2.std(),5)
e = round(r2_notails_z2.mean(),5)
f = round(r2_notails_z2.std(),5)
print("Zeta Strand 2 Statistics")
print("The wt z2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt z2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 z2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 z2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 z2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 z2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Zeta Strand 2 Statistics
# The wt z2 mean and standard devation are -51.41716  +/-  6.65459
# The range of values within one standard deviation of the wt z2 mean are from  -58.07175  to  -44.76257
# The r1 z2 mean and standard devation are -54.79667  +/-  7.31821
# The range of values within one standard deviation of the r1 z2 mean are from  -62.11488  to  -47.47846
# The difference in mean value between wt and r1 is 3.37951
# The r2 z2 mean and standard devation are -56.16298  +/-  6.69197
# The range of values within one standard deviation of the r2 z2 mean are from  -62.85495  to  -49.47101
# The difference in mean value between wt and r2 is 4.74582

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_e = np.linspace(-140, -40, 30)
ax0.hist([wt_notails_e1, r1_notails_e1], bins_e, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Epsilon 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-140, -40)
ax0.set_ylim(0, 140)
ax1.hist([wt_notails_e1, r2_notails_e1], bins_e, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Epsilon 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-140, -40)
ax1.set_ylim(0, 140)
ax2.hist([wt_notails_e2, r1_notails_e2], bins_e, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Epsilon 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-140, -40)
ax2.set_ylim(0, 140)
ax3.hist([wt_notails_e2, r2_notails_e2], bins_e, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Epsilon 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-140, -40)
ax3.set_ylim(0, 140)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_z = np.linspace(-80, -30, 30)
ax0.hist([wt_notails_z1, r1_notails_z1], bins_z, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Zeta 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-80, -30)
ax0.set_ylim(0, 150)
ax1.hist([wt_notails_z1, r2_notails_z1], bins_z, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Zeta 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-80, -30)
ax1.set_ylim(0, 150)
ax2.hist([wt_notails_z2, r1_notails_z2], bins_z, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Zeta 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-80, -30)
ax2.set_ylim(0, 150)
ax3.hist([wt_notails_z2, r2_notails_z2], bins_z, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Zeta 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-80, -30)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
wt_notails_chi1 = df_wt_notails.loc[:,'Chi_1']
r1_notails_chi1 = df_r1_notails.loc[:,'Chi_1']
r2_notails_chi1 = df_r2_notails.loc[:,'Chi_1']

wt_notails_chi2 = df_wt_notails.loc[:,'Chi_2']
r1_notails_chi2 = df_r1_notails.loc[:,'Chi_2']
r2_notails_chi2 = df_r2_notails.loc[:,'Chi_2']

wt_notails_phase1 = df_wt_notails.loc[:,'Phase_1']
r1_notails_phase1 = df_r1_notails.loc[:,'Phase_1']
r2_notails_phase1 = df_r2_notails.loc[:,'Phase_1']

wt_notails_phase2 = df_wt_notails.loc[:,'Phase_2']
r1_notails_phase2 = df_r1_notails.loc[:,'Phase_2']
r2_notails_phase2 = df_r2_notails.loc[:,'Phase_2']

wt_notails_ampli1 = df_wt_notails.loc[:,'Ampli_1']
r1_notails_ampli1 = df_r1_notails.loc[:,'Ampli_1']
r2_notails_ampli1 = df_r2_notails.loc[:,'Ampli_1']

wt_notails_ampli2 = df_wt_notails.loc[:,'Ampli_2']
r1_notails_ampli2 = df_r1_notails.loc[:,'Ampli_2']
r2_notails_ampli2 = df_r2_notails.loc[:,'Ampli_2']

# %%
a = round(wt_notails_chi1.mean(),5)
b = round(wt_notails_chi1.std(),5)
c = round(r1_notails_chi1.mean(),5)
d = round(r1_notails_chi1.std(),5)
e = round(r2_notails_chi1.mean(),5)
f = round(r2_notails_chi1.std(),5)
print("Chi Strand 1 Statistics")
print("The wt chi1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt chi1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 chi1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 chi1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 chi1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 chi1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Chi Strand 1 Statistics
# The wt chi1 mean and standard devation are -112.80405  +/-  1.51209
# The range of values within one standard deviation of the wt chi1 mean are from  -114.31614  to  -111.29196
# The r1 chi1 mean and standard devation are -113.24702  +/-  1.71802
# The range of values within one standard deviation of the r1 chi1 mean are from  -114.96504  to  -111.529
# The difference in mean value between wt and r1 is 0.44297
# The r2 chi1 mean and standard devation are -113.08972  +/-  1.5747
# The range of values within one standard deviation of the r2 chi1 mean are from  -114.66442  to  -111.51502
# The difference in mean value between wt and r2 is 0.28567

# %%
a = round(wt_notails_chi2.mean(),5)
b = round(wt_notails_chi2.std(),5)
c = round(r1_notails_chi2.mean(),5)
d = round(r1_notails_chi2.std(),5)
e = round(r2_notails_chi2.mean(),5)
f = round(r2_notails_chi2.std(),5)
print("Chi Strand 2 Statistics")
print("The wt chi2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt chi2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 chi2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 chi2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 chi2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 chi2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Chi Strand 2 Statistics
# The wt chi2 mean and standard devation are -112.18492  +/-  1.4985
# The range of values within one standard deviation of the wt chi2 mean are from  -113.68342  to  -110.68642
# The r1 chi2 mean and standard devation are -112.09482  +/-  1.38175
# The range of values within one standard deviation of the r1 chi2 mean are from  -113.47657  to  -110.71307
# The difference in mean value between wt and r1 is -0.0901
# The r2 chi2 mean and standard devation are -112.41426  +/-  1.50616
# The range of values within one standard deviation of the r2 chi2 mean are from  -113.92042  to  -110.9081
# The difference in mean value between wt and r2 is 0.22934

# %%
a = round(wt_notails_phase1.mean(),5)
b = round(wt_notails_phase1.std(),5)
c = round(r1_notails_phase1.mean(),5)
d = round(r1_notails_phase1.std(),5)
e = round(r2_notails_phase1.mean(),5)
f = round(r2_notails_phase1.std(),5)
print("Phase Strand 1 Statistics")
print("The wt phase1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt phase1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 phase1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 phase1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 phase1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 phase1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Phase Strand 1 Statistics
# The wt phase1 mean and standard devation are 116.99788  +/-  8.262
# The range of values within one standard deviation of the wt phase1 mean are from  108.73588  to  125.25988
# The r1 phase1 mean and standard devation are 119.94907  +/-  8.15145
# The range of values within one standard deviation of the r1 phase1 mean are from  111.79762  to  128.10052
# The difference in mean value between wt and r1 is -2.95119
# The r2 phase1 mean and standard devation are 116.85083  +/-  8.3237
# The range of values within one standard deviation of the r2 phase1 mean are from  108.52713  to  125.17453
# The difference in mean value between wt and r2 is 0.14705

# %%
a = round(wt_notails_phase2.mean(),5)
b = round(wt_notails_phase2.std(),5)
c = round(r1_notails_phase2.mean(),5)
d = round(r1_notails_phase2.std(),5)
e = round(r2_notails_phase2.mean(),5)
f = round(r2_notails_phase2.std(),5)
print("Phase Strand 2 Statistics")
print("The wt phase2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt phase2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 phase2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 phase2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 phase2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 phase2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Phase Strand 2 Statistics
# The wt phase2 mean and standard devation are 117.22383  +/-  8.70626
# The range of values within one standard deviation of the wt phase2 mean are from  108.51757  to  125.93009
# The r1 phase2 mean and standard devation are 115.66846  +/-  8.19316
# The range of values within one standard deviation of the r1 phase2 mean are from  107.4753  to  123.86162
# The difference in mean value between wt and r1 is 1.55537
# The r2 phase2 mean and standard devation are 118.35558  +/-  8.32281
# The range of values within one standard deviation of the r2 phase2 mean are from  110.03277  to  126.67839
# The difference in mean value between wt and r2 is -1.13175

# %%
a = round(wt_notails_ampli1.mean(),5)
b = round(wt_notails_ampli1.std(),5)
c = round(r1_notails_ampli1.mean(),5)
d = round(r1_notails_ampli1.std(),5)
e = round(r2_notails_ampli1.mean(),5)
f = round(r2_notails_ampli1.std(),5)
print("Amplitude Strand 1 Statistics")
print("The wt ampli1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt ampli1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 ampli1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 ampli1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 zampli1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 ampli1 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Amplitude Strand 1 Statistics
# The wt ampli1 mean and standard devation are 41.06751  +/-  0.49363
# The range of values within one standard deviation of the wt ampli1 mean are from  40.57388  to  41.56114
# The r1 ampli1 mean and standard devation are 41.16149  +/-  0.49774
# The range of values within one standard deviation of the r1 ampli1 mean are from  40.66375  to  41.65923
# The difference in mean value between wt and r1 is -0.09398
# The r2 zampli1 mean and standard devation are 40.9875  +/-  0.51263
# The range of values within one standard deviation of the r2 ampli1 mean are from  40.47487  to  41.50013
# The difference in mean value between wt and r2 is 0.08001

# %%
a = round(wt_notails_ampli2.mean(),5)
b = round(wt_notails_ampli2.std(),5)
c = round(r1_notails_ampli2.mean(),5)
d = round(r1_notails_ampli2.std(),5)
e = round(r2_notails_ampli2.mean(),5)
f = round(r2_notails_ampli2.std(),5)
print("Amplitude Strand 2 Statistics")
print("The wt ampli2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt ampli2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 ampli2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 ampli2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 ampli2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 ampli2 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Amplitude Strand 2 Statistics
# The wt ampli2 mean and standard devation are 41.44472  +/-  0.49008
# The range of values within one standard deviation of the wt ampli2 mean are from  40.95464  to  41.9348
# The r1 ampli2 mean and standard devation are 41.17343  +/-  0.52719
# The range of values within one standard deviation of the r1 ampli2 mean are from  40.64624  to  41.70062
# The difference in mean value between wt and r1 is 0.27129
# The r2 ampli2 mean and standard devation are 41.18809  +/-  0.51469
# The range of values within one standard deviation of the r2 ampli2 mean are from  40.6734  to  41.70278
# The difference in mean value between wt and r2 is 0.25663

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_chi = np.linspace(-118, -105, 30)
ax0.hist([wt_notails_chi1, r1_notails_chi1], bins_chi, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Chi 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(-118, -105)
ax0.set_ylim(0, 150)
ax1.hist([wt_notails_chi1, r2_notails_chi1], bins_chi, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Chi 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-118, -105)
ax1.set_ylim(0, 150)
ax2.hist([wt_notails_chi2, r1_notails_chi2], bins_chi, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Chi 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(-118, -105)
ax2.set_ylim(0, 150)
ax3.hist([wt_notails_chi2, r2_notails_chi2], bins_chi, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Chi 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-118, -105)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_phase = np.linspace(85, 145, 30)
ax0.hist([wt_notails_phase1, r1_notails_phase1], bins_phase, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Phase 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(85, 145)
ax0.set_ylim(0, 120)
ax1.hist([wt_notails_phase1, r2_notails_phase1], bins_phase, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Phase 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(85, 145)
ax1.set_ylim(0, 120)
ax2.hist([wt_notails_phase2, r1_notails_phase2], bins_phase, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Phase 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(85, 145)
ax2.set_ylim(0, 120)
ax3.hist([wt_notails_phase2, r2_notails_phase2], bins_phase, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Phase 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(85, 145)
ax3.set_ylim(0, 120)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2,figsize=(10,6))
bins_ampli = np.linspace(39, 43.5, 30)
ax0.hist([wt_notails_ampli1, r1_notails_ampli1], bins_ampli, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Amplitude 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(39, 43.5)
ax0.set_ylim(0, 150)
ax1.hist([wt_notails_ampli1, r2_notails_ampli1], bins_ampli, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Amplitude 1: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(39, 43.5)
ax1.set_ylim(0, 150)
ax2.hist([wt_notails_ampli2, r1_notails_ampli2], bins_ampli, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Amplitude 2: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(39, 43.5)
ax2.set_ylim(0, 150)
ax3.hist([wt_notails_ampli2, r2_notails_ampli2], bins_ampli, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Amplitude 2: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(39, 43.5)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
wt_notails_hris = df_wt_notails.loc[:,'H-ris']
r1_notails_hris = df_r1_notails.loc[:,'H-ris']
r2_notails_hris = df_r2_notails.loc[:,'H-ris']

wt_notails_htwi = df_wt_notails.loc[:,'H-twi']
r1_notails_htwi = df_r1_notails.loc[:,'H-twi']
r2_notails_htwi = df_r2_notails.loc[:,'H-twi']

wt_notails_ax_bend = df_wt_notails.loc[:,'Ax-Bend']
r1_notails_ax_bend = df_r1_notails.loc[:,'Ax-Bend']
r2_notails_ax_bend = df_r2_notails.loc[:,'Ax-Bend']

# %%
a = round(wt_notails_hris.mean(),5)
b = round(wt_notails_hris.std(),5)
c = round(r1_notails_hris.mean(),5)
d = round(r1_notails_hris.std(),5)
e = round(r2_notails_hris.mean(),5)
f = round(r2_notails_hris.std(),5)
print("H-Rise Statistics")
print("The wt hris mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt hris mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 hris mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 hris mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 hris mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 hris mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# H-Rise Statistics
# The wt hris mean and standard devation are 3.35914  +/-  0.01698
# The range of values within one standard deviation of the wt hris mean are from  3.34216  to  3.37612
# The r1 hris mean and standard devation are 3.36579  +/-  0.02044
# The range of values within one standard deviation of the r1 hris mean are from  3.34535  to  3.38623
# The difference in mean value between wt and r1 is -0.00665
# The r2 hris mean and standard devation are 3.3431  +/-  0.021
# The range of values within one standard deviation of the r2 hris mean are from  3.3221  to  3.3641
# The difference in mean value between wt and r2 is 0.01604

# %%
a = round(wt_notails_htwi.mean(),5)
b = round(wt_notails_htwi.std(),5)
c = round(r1_notails_htwi.mean(),5)
d = round(r1_notails_htwi.std(),5)
e = round(r2_notails_htwi.mean(),5)
f = round(r2_notails_htwi.std(),5)
print("H-Twist Strand 2 Statistics")
print("The wt htwi mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt htwi mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 htwi mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 htwi mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 htwi mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 htwi mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# H-Twist Strand 2 Statistics
# The wt htwi mean and standard devation are 35.30488  +/-  0.09279
# The range of values within one standard deviation of the wt htwi mean are from  35.21209  to  35.39767
# The r1 htwi mean and standard devation are 35.26725  +/-  0.11997
# The range of values within one standard deviation of the r1 htwi mean are from  35.14728  to  35.38722
# The difference in mean value between wt and r1 is 0.03763
# The r2 htwi mean and standard devation are 35.46153  +/-  0.11265
# The range of values within one standard deviation of the r2 htwi mean are from  35.34888  to  35.57418
# The difference in mean value between wt and r2 is -0.15665

# %%
a = round(wt_notails_ax_bend.mean(),5)
b = round(wt_notails_ax_bend.std(),5)
c = round(r1_notails_ax_bend.mean(),5)
d = round(r1_notails_ax_bend.std(),5)
e = round(r2_notails_ax_bend.mean(),5)
f = round(r2_notails_ax_bend.std(),5)
print("H-Axis Bend Strand 2 Statistics")
print("The wt ax_bend mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt ax_bend mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 ax_bend mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 ax_bend mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 ax_bend mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 ax_bend mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# H-Axis Bend Strand 2 Statistics
# The wt ax_bend mean and standard devation are 4.9303  +/-  0.08152
# The range of values within one standard deviation of the wt ax_bend mean are from  4.84878  to  5.01182
# The r1 ax_bend mean and standard devation are 4.89427  +/-  0.0829
# The range of values within one standard deviation of the r1 ax_bend mean are from  4.81137  to  4.97717
# The difference in mean value between wt and r1 is 0.03603
# The r2 ax_bend mean and standard devation are 4.89684  +/-  0.08781
# The range of values within one standard deviation of the r2 ax_bend mean are from  4.80903  to  4.98465
# The difference in mean value between wt and r2 is 0.03346

# %%
fig, ((ax0, ax1),(ax2,ax3),(ax4,ax5)) = plt.subplots(nrows=3, ncols=2, figsize=(10,8))
bins_hrise = np.linspace(3.25, 3.45, 30)
ax0.hist([wt_notails_hris, r1_notails_hris], bins_hrise, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('H-Rise: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(3.25, 3.45)
ax0.set_ylim(0, 160)
ax1.hist([wt_notails_hris, r2_notails_hris], bins_hrise, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('H-Rise: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(3.25, 3.45)
ax1.set_ylim(0, 160)
bins_htwi = np.linspace(34.8, 35.8, 30)
ax2.hist([wt_notails_htwi, r1_notails_htwi], bins_htwi, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('H-Twist: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(34.8, 35.8)
ax2.set_ylim(0, 160)
ax3.hist([wt_notails_htwi, r2_notails_htwi], bins_htwi, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('H-Twist: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(34.8, 35.8)
ax3.set_ylim(0, 160)
bins_ax_bend = np.linspace(4.6, 5.2, 30)
ax4.hist([wt_notails_ax_bend, r1_notails_ax_bend], bins_ax_bend, label=['WT', 'Reg1'], color=['blue','red'])
ax4.legend(loc='upper right')
ax4.set_xlabel('Value ($^\circ$)')
ax4.set_ylabel('Frame Count')
ax4.set_title('Helical Axis Bend: Wild-Type vs Region 1 Defect ')
ax4.set_xlim(4.6, 5.2)
ax4.set_ylim(0, 160)
ax5.hist([wt_notails_ax_bend, r2_notails_ax_bend], bins_ax_bend, label=['WT', 'Reg2'], color=['blue','orange'])
ax5.legend(loc='upper right')
ax5.set_xlabel('Value ($^\circ$)')
ax5.set_ylabel('Frame Count')
ax5.set_title('Helical Axis Bend: Wild-Type vs Region 2 Defect ')
ax5.set_xlim(4.6, 5.2)
ax5.set_ylim(0, 160)
fig.tight_layout()

# %%
wt_notails_w12 = df_wt_notails.loc[:,'W12']
r1_notails_w12 = df_r1_notails.loc[:,'W12']
r2_notails_w12 = df_r2_notails.loc[:,'W12']

wt_notails_d12 = df_wt_notails.loc[:,'D12']
r1_notails_d12 = df_r1_notails.loc[:,'D12']
r2_notails_d12 = df_r2_notails.loc[:,'D12']

# %%
a = round(wt_notails_w12.mean(),5)
b = round(wt_notails_w12.std(),5)
c = round(r1_notails_w12.mean(),5)
d = round(r1_notails_w12.std(),5)
e = round(r2_notails_w12.mean(),5)
f = round(r2_notails_w12.std(),5)
print("Minor Groove Width Strand 2 Statistics")
print("The wt w12 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt w12 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 w12 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 w12 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 w12 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 w12 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Minor Groove Width Strand 2 Statistics
# The wt w12 mean and standard devation are 5.06611  +/-  0.12029
# The range of values within one standard deviation of the wt w12 mean are from  4.94582  to  5.1864
# The r1 w12 mean and standard devation are 5.0622  +/-  0.14905
# The range of values within one standard deviation of the r1 w12 mean are from  4.91315  to  5.21125
# The difference in mean value between wt and r1 is 0.00391
# The r2 w12 mean and standard devation are 5.25184  +/-  0.11689
# The range of values within one standard deviation of the r2 w12 mean are from  5.13495  to  5.36873
# The difference in mean value between wt and r2 is -0.18573

# %%
a = round(wt_notails_d12.mean(),5)
b = round(wt_notails_d12.std(),5)
c = round(r1_notails_d12.mean(),5)
d = round(r1_notails_d12.std(),5)
e = round(r2_notails_d12.mean(),5)
f = round(r2_notails_d12.std(),5)
print("Minor Groove Depth Strand 2 Statistics")
print("The wt d12 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt d12 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 d12 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 d12 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 d12 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 d12 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Minor Groove Depth Strand 2 Statistics
# The wt d12 mean and standard devation are 5.25856  +/-  0.04378
# The range of values within one standard deviation of the wt d12 mean are from  5.21478  to  5.30234
# The r1 d12 mean and standard devation are 5.2487  +/-  0.0444
# The range of values within one standard deviation of the r1 d12 mean are from  5.2043  to  5.2931
# The difference in mean value between wt and r1 is 0.00986
# The r2 d12 mean and standard devation are 5.21313  +/-  0.05022
# The range of values within one standard deviation of the r2 d12 mean are from  5.16291  to  5.26335
# The difference in mean value between wt and r2 is 0.04543

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_w12 = np.linspace(4.6, 5.7, 30)
ax0.hist([wt_notails_w12, r1_notails_w12], bins_w12, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Minor W: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(4.6, 5.7)
ax0.set_ylim(0, 160)
ax1.hist([wt_notails_w12, r2_notails_w12], bins_w12, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Minor W: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(4.6, 5.7)
ax1.set_ylim(0, 160)
bins_d12 = np.linspace(5.0, 5.5, 30)
ax2.hist([wt_notails_d12, r1_notails_d12], bins_d12, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Minor D: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(5.0, 5.5)
ax2.set_ylim(0, 180)
ax3.hist([wt_notails_d12, r2_notails_d12], bins_d12, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Minor D: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(5.0, 5.5)
ax3.set_ylim(0, 180)
fig.tight_layout()

# %%
wt_notails_w21 = df_wt_notails.loc[:,'W21']
r1_notails_w21 = df_r1_notails.loc[:,'W21']
r2_notails_w21 = df_r2_notails.loc[:,'W21']

wt_notails_d21 = df_wt_notails.loc[:,'D21']
r1_notails_d21 = df_r1_notails.loc[:,'D21']
r2_notails_d21 = df_r2_notails.loc[:,'D21']

# %%
a = round(wt_notails_w21.mean(),5)
b = round(wt_notails_w21.std(),5)
c = round(r1_notails_w21.mean(),5)
d = round(r1_notails_w21.std(),5)
e = round(r2_notails_w21.mean(),5)
f = round(r2_notails_w21.std(),5)
print("Major Groove Width Strand 2 Statistics")
print("The wt w21 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt w21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 w21 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 w21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 w21 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 w21 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Major Groove Width Strand 2 Statistics
# The wt w21 mean and standard devation are 11.50791  +/-  0.13155
# The range of values within one standard deviation of the wt w21 mean are from  11.37636  to  11.63946
# The r1 w21 mean and standard devation are 11.61589  +/-  0.1496
# The range of values within one standard deviation of the r1 w21 mean are from  11.46629  to  11.76549
# The difference in mean value between wt and r1 is -0.10798
# The r2 w21 mean and standard devation are 11.48809  +/-  0.14199
# The range of values within one standard deviation of the r2 w21 mean are from  11.3461  to  11.63008
# The difference in mean value between wt and r2 is 0.01982

# %%
a = round(wt_notails_d21.mean(),5)
b = round(wt_notails_d21.std(),5)
c = round(r1_notails_d21.mean(),5)
d = round(r1_notails_d21.std(),5)
e = round(r2_notails_d21.mean(),5)
f = round(r2_notails_d21.std(),5)
print("Major Groove Depth Strand 2 Statistics")
print("The wt d21 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt dd2112 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 d21 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))
print("The r2 d21 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the r2 d21 mean are from  " + str(round(e-f,5)) + "  to  " + str(round(e+f,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-e,5)))
# Out:
# Major Groove Depth Strand 2 Statistics
# The wt d21 mean and standard devation are 4.72239  +/-  0.13115
# The range of values within one standard deviation of the wt dd2112 mean are from  4.59124  to  4.85354
# The r1 d21 mean and standard devation are 4.82342  +/-  0.14518
# The range of values within one standard deviation of the r1 d21 mean are from  4.67824  to  4.9686
# The difference in mean value between wt and r1 is -0.10103
# The r2 d21 mean and standard devation are 4.82554  +/-  0.1378
# The range of values within one standard deviation of the r2 d21 mean are from  4.68774  to  4.96334
# The difference in mean value between wt and r2 is -0.10315

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_w21 = np.linspace(10.9, 12.1, 30)
ax0.hist([wt_notails_w21, r1_notails_w21], bins_w21, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Major W: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(10.9, 12.1)
ax0.set_ylim(0, 160)
ax1.hist([wt_notails_w21, r2_notails_w21], bins_w21, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Major W: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(10.9, 12.1)
ax1.set_ylim(0, 160)
bins_d21 = np.linspace(4.3, 5.3, 30)
ax2.hist([wt_notails_d21, r1_notails_d21], bins_d21, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Major D: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(4.3, 5.3)
ax2.set_ylim(0, 120)
ax3.hist([wt_notails_d21, r2_notails_d21], bins_d21, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Major D: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(4.3, 5.3)
ax3.set_ylim(0, 120)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3),(ax4,ax5)) = plt.subplots(nrows=3, ncols=2, figsize=(10,8))
ax0.hist([wt_notails_ax_bend, r1_notails_ax_bend], bins_ax_bend, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Helical Axis Bend: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(4.6, 5.2)
ax0.set_ylim(0, 120)
ax1.hist([wt_notails_ax_bend, r2_notails_ax_bend], bins_ax_bend, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Helical Axis Bend: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(4.6, 5.2)
ax1.set_ylim(0, 120)
ax2.hist([wt_notails_rise, r1_notails_rise], bins_rise, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Rise: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(3.34, 3.43)
ax2.set_ylim(0, 120)
ax3.hist([wt_notails_rise, r2_notails_rise], bins_rise, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Rise: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(3.34, 3.43)
ax3.set_ylim(0, 120)
ax4.hist([wt_notails_d12, r1_notails_d12], bins_d12, label=['WT', 'Reg1'], color=['blue','red'])
ax4.legend(loc='upper right')
ax4.set_xlabel('Value ($\AA$)')
ax4.set_ylabel('Frame Count')
ax4.set_title('Minor Groove Depth: Wild-Type vs Region 1 Defect ')
ax4.set_xlim(5.0, 5.5)
ax4.set_ylim(0, 180)
ax5.hist([wt_notails_d12, r2_notails_d12], bins_d12, label=['WT', 'Reg2'], color=['blue','orange'])
ax5.legend(loc='upper right')
ax5.set_xlabel('Value ($\AA$)')
ax5.set_ylabel('Frame Count')
ax5.set_title('Minor Groove Depth: Wild-Type vs Region 2 Defect ')
ax5.set_xlim(5.0, 5.5)
ax5.set_ylim(0, 180)
fig.tight_layout()

# %%
df_wt_sec1 = pd.read_csv('./wt_0_weka_inputs/sec2_wt_G_0_weka_input.csv')
df_wt_sec2 = pd.read_csv('./wt_0_weka_inputs/sec3_wt_G_0_weka_input.csv')
df_wt_sec3 = pd.read_csv('./wt_0_weka_inputs/sec4_wt_G_0_weka_input.csv')
df_wt_sec4 = pd.read_csv('./wt_0_weka_inputs/sec5_wt_G_0_weka_input.csv')
wt_sec1_twist = df_wt_sec1.loc[:,'Twist']
wt_sec2_twist = df_wt_sec2.loc[:,'Twist']
wt_sec3_twist = df_wt_sec3.loc[:,'Twist']
wt_sec4_twist = df_wt_sec4.loc[:,'Twist']

df_r2_sec1 = pd.read_csv('./8oxoG_0_reg2_weka_inputs/sec2_8oxoG_0_reg2_weka_input.csv')
df_r2_sec2 = pd.read_csv('./8oxoG_0_reg2_weka_inputs/sec3_8oxoG_0_reg2_weka_input.csv')
df_r2_sec3 = pd.read_csv('./8oxoG_0_reg2_weka_inputs/sec4_8oxoG_0_reg2_weka_input.csv')
df_r2_sec4 = pd.read_csv('./8oxoG_0_reg2_weka_inputs/sec5_8oxoG_0_reg2_weka_input.csv')
r2_sec1_twist = df_r2_sec1.loc[:,'Twist']
r2_sec2_twist = df_r2_sec2.loc[:,'Twist']
r2_sec3_twist = df_r2_sec3.loc[:,'Twist']
r2_sec4_twist = df_r2_sec4.loc[:,'Twist']

# %%
a = round(wt_sec1_twist.mean(),5)
b = round(wt_sec1_twist.std(),5)
c = round(r2_sec1_twist.mean(),5)
d = round(r2_sec1_twist.std(),5)
e = round(wt_sec2_twist.mean(),5)
f = round(wt_sec2_twist.std(),5)
g = round(r2_sec2_twist.mean(),5)
h = round(r2_sec2_twist.std(),5)
i = round(wt_sec3_twist.mean(),5)
j = round(wt_sec3_twist.std(),5)
k = round(r2_sec3_twist.mean(),5)
l = round(r2_sec3_twist.std(),5)
m = round(wt_sec4_twist.mean(),5)
n = round(wt_sec4_twist.std(),5)
o = round(r2_sec4_twist.mean(),5)
p = round(r2_sec4_twist.std(),5)
print("Twist Sections 1-4 Statistics")
print("The wt sec1 twist mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 twist mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec1 twist mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r2 sec1 twist mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-c,5)))

print("The wt sec2 twist mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 twist mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec2 twist mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r2 sec2 twist mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(e-g,5)))

print("The wt sec3 twist mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 twist mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec3 twist mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r2 sec3 twist mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(i-k,5)))

print("The wt sec4 twist mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 twist mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec4 twist mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r2 sec4 twist mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(m-o,5)))
# Out:
# Twist Sections 1-4 Statistics
# The wt sec1 twist mean and standard devation are 35.31982  +/-  0.41938
# The range of values within one standard deviation of the wt sec1 twist mean are from  34.90044  to  35.7392
# The r2 sec1 twist mean and standard devation are 35.76385  +/-  0.41076
# The range of values within one standard deviation of the r2 sec1 twist mean are from  35.35309  to  36.17461
# The difference in mean value between wt and r2 is -0.44403
# The wt sec2 twist mean and standard devation are 34.7444  +/-  0.43755
# The range of values within one standard deviation of the wt sec2 twist mean are from  34.90044  to  35.7392
# The r2 sec2 twist mean and standard devation are 34.69912  +/-  0.41889
# The range of values within one standard deviation of the r2 sec2 twist mean are from  35.35309  to  36.17461
# The difference in mean value between wt and r2 is 0.04528
# The wt sec3 twist mean and standard devation are 34.30034  +/-  0.35047
# ...

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_twist = np.linspace(33, 37, 30)
ax0.hist([wt_sec1_twist, r2_sec1_twist], bins_sec_twist, label=['WT', 'Reg2'], color=['blue','orange'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Twist Section 1: Wild-Type vs Region 2 Defect ')
ax0.set_xlim(33, 37)
ax0.set_ylim(0, 180)
ax1.hist([wt_sec2_twist, r2_sec2_twist], bins_sec_twist, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Twist Section 2: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(33, 37)
ax1.set_ylim(0, 180)
ax2.hist([wt_sec3_twist, r2_sec3_twist], bins_sec_twist, label=['WT', 'Reg2'], color=['blue','orange'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Twist Section 3: Wild-Type vs Region 2 Defect ')
ax2.set_xlim(33, 37)
ax2.set_ylim(0, 180)
ax3.hist([wt_sec4_twist, r2_sec4_twist], bins_sec_twist, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Twist Section 4: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(33, 37)
ax3.set_ylim(0, 180)
fig.tight_layout()

# %%
wt_sec1_xdisp = df_wt_sec1.loc[:,'Xdisp']
wt_sec2_xdisp = df_wt_sec2.loc[:,'Xdisp']
wt_sec3_xdisp = df_wt_sec3.loc[:,'Xdisp']
wt_sec4_xdisp = df_wt_sec4.loc[:,'Xdisp']
r2_sec1_xdisp = df_r2_sec1.loc[:,'Xdisp']
r2_sec2_xdisp = df_r2_sec2.loc[:,'Xdisp']
r2_sec3_xdisp = df_r2_sec3.loc[:,'Xdisp']
r2_sec4_xdisp = df_r2_sec4.loc[:,'Xdisp']

# %%
a = round(wt_sec1_xdisp.mean(),5)
b = round(wt_sec1_xdisp.std(),5)
c = round(r2_sec1_xdisp.mean(),5)
d = round(r2_sec1_xdisp.std(),5)
e = round(wt_sec2_xdisp.mean(),5)
f = round(wt_sec2_xdisp.std(),5)
g = round(r2_sec2_xdisp.mean(),5)
h = round(r2_sec2_xdisp.std(),5)
i = round(wt_sec3_xdisp.mean(),5)
j = round(wt_sec3_xdisp.std(),5)
k = round(r2_sec3_xdisp.mean(),5)
l = round(r2_sec3_xdisp.std(),5)
m = round(wt_sec4_xdisp.mean(),5)
n = round(wt_sec4_xdisp.std(),5)
o = round(r2_sec4_xdisp.mean(),5)
p = round(r2_sec4_xdisp.std(),5)
print("X-Displacement Sections 1-4 Statistics")
print("The wt sec1 xdisp mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 xdisp mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec1 xdisp mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r2 sec1 xdisp mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-c,5)))

print("The wt sec2 xdisp mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 xdisp mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec2 xdisp mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r2 sec2 xdisp mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(e-g,5)))

print("The wt sec3 xdisp mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 xdisp mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec3 xdisp mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r2 sec3 xdisp mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(i-k,5)))

print("The wt sec4 xdisp mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 xdisp mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec4 xdisp mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r2 sec4 xdisp mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(m-o,5)))
# Out:
# X-Displacement Sections 1-4 Statistics
# The wt sec1 xdisp mean and standard devation are -0.18881  +/-  0.14456
# The range of values within one standard deviation of the wt sec1 xdisp mean are from  -0.33337  to  -0.04425
# The r2 sec1 xdisp mean and standard devation are -0.05875  +/-  0.14313
# The range of values within one standard deviation of the r2 sec1 xdisp mean are from  -0.20188  to  0.08438
# The difference in mean value between wt and r2 is -0.13006
# The wt sec2 xdisp mean and standard devation are -0.21409  +/-  0.14168
# The range of values within one standard deviation of the wt sec2 xdisp mean are from  -0.33337  to  -0.04425
# The r2 sec2 xdisp mean and standard devation are -0.4355  +/-  0.14532
# The range of values within one standard deviation of the r2 sec2 xdisp mean are from  -0.20188  to  0.08438
# The difference in mean value between wt and r2 is 0.22141
# The wt sec3 xdisp mean and standard devation are -0.38601  +/-  0.13696
# ...

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_xdips = np.linspace(-0.9, 0.4, 30)
ax0.hist([wt_sec1_xdisp, r2_sec1_xdisp], bins_sec_xdips, label=['WT', 'Reg2'], color=['blue','orange'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('X-Disp Section 1: Wild-Type vs Region 2 Defect ')
ax0.set_xlim(-0.9, 0.4)
ax0.set_ylim(0, 150)
ax1.hist([wt_sec2_xdisp, r2_sec2_xdisp], bins_sec_xdips, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('X-Disp Section 2: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-0.9, 0.4)
ax1.set_ylim(0, 150)
ax2.hist([wt_sec3_xdisp, r2_sec3_xdisp], bins_sec_xdips, label=['WT', 'Reg2'], color=['blue','orange'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('X-Disp Section 3: Wild-Type vs Region 2 Defect ')
ax2.set_xlim(-0.9, 0.4)
ax2.set_ylim(0, 150)
ax3.hist([wt_sec4_xdisp, r2_sec4_xdisp], bins_sec_xdips, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('X-Disp Section 4: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-0.9, 0.4)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
wt_sec1_inclin = df_wt_sec1.loc[:,'Inclin']
wt_sec2_inclin = df_wt_sec2.loc[:,'Inclin']
wt_sec3_inclin = df_wt_sec3.loc[:,'Inclin']
wt_sec4_inclin = df_wt_sec4.loc[:,'Inclin']
r2_sec1_inclin = df_r2_sec1.loc[:,'Inclin']
r2_sec2_inclin = df_r2_sec2.loc[:,'Inclin']
r2_sec3_inclin = df_r2_sec3.loc[:,'Inclin']
r2_sec4_inclin = df_r2_sec4.loc[:,'Inclin']

# %%
a = round(wt_sec1_inclin.mean(),5)
b = round(wt_sec1_inclin.std(),5)
c = round(r2_sec1_inclin.mean(),5)
d = round(r2_sec1_inclin.std(),5)
e = round(wt_sec2_inclin.mean(),5)
f = round(wt_sec2_inclin.std(),5)
g = round(r2_sec2_inclin.mean(),5)
h = round(r2_sec2_inclin.std(),5)
i = round(wt_sec3_inclin.mean(),5)
j = round(wt_sec3_inclin.std(),5)
k = round(r2_sec3_inclin.mean(),5)
l = round(r2_sec3_inclin.std(),5)
m = round(wt_sec4_inclin.mean(),5)
n = round(wt_sec4_inclin.std(),5)
o = round(r2_sec4_inclin.mean(),5)
p = round(r2_sec4_inclin.std(),5)
print("Inclination Sections 1-4 Statistics")
print("The wt sec1 inclin mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 inclin mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec1 inclin mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r2 sec1 inclin mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-c,5)))

print("The wt sec2 inclin mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 inclin mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec2 inclin mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r2 sec2 inclin mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(e-g,5)))

print("The wt sec3 inclin mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 inclin mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec3 inclin mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r2 sec3 inclin mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(i-k,5)))

print("The wt sec4 inclin mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 inclin mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec4 inclin mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r2 sec4 inclin mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(m-o,5)))
# Out:
# Inclination Sections 1-4 Statistics
# The wt sec1 inclin mean and standard devation are -1.38239  +/-  1.34588
# The range of values within one standard deviation of the wt sec1 inclin mean are from  -2.72827  to  -0.03651
# The r2 sec1 inclin mean and standard devation are -0.82916  +/-  1.3527
# The range of values within one standard deviation of the r2 sec1 inclin mean are from  -2.18186  to  0.52354
# The difference in mean value between wt and r2 is -0.55323
# The wt sec2 inclin mean and standard devation are -2.96524  +/-  1.36002
# The range of values within one standard deviation of the wt sec2 inclin mean are from  -2.72827  to  -0.03651
# The r2 sec2 inclin mean and standard devation are -2.95754  +/-  1.44954
# The range of values within one standard deviation of the r2 sec2 inclin mean are from  -2.18186  to  0.52354
# The difference in mean value between wt and r2 is -0.0077
# The wt sec3 inclin mean and standard devation are -0.53483  +/-  1.52219
# ...

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_inclin = np.linspace(-8, 4.5, 30)
ax0.hist([wt_sec1_inclin, r2_sec1_inclin], bins_sec_inclin, label=['WT', 'Reg2'], color=['blue','orange'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Inclination Section 1: Wild-Type vs Region 2 Defect ')
ax0.set_xlim(-8, 4.5)
ax0.set_ylim(0, 150)
ax1.hist([wt_sec2_inclin, r2_sec2_inclin], bins_sec_inclin, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Inclination Section 2: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(-8, 4.5)
ax1.set_ylim(0, 150)
ax2.hist([wt_sec3_inclin, r2_sec3_inclin], bins_sec_inclin, label=['WT', 'Reg2'], color=['blue','orange'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Inclination Section 3: Wild-Type vs Region 2 Defect ')
ax2.set_xlim(-8, 4.5)
ax2.set_ylim(0, 150)
ax3.hist([wt_sec4_inclin, r2_sec4_inclin], bins_sec_inclin, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Inclination Section 4: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(-8, 4.5)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
wt_sec1_d1 = df_wt_sec1.loc[:,'Delta_1']
wt_sec2_d1 = df_wt_sec2.loc[:,'Delta_1']
wt_sec3_d1 = df_wt_sec3.loc[:,'Delta_1']
wt_sec4_d1 = df_wt_sec4.loc[:,'Delta_1']
r2_sec1_d1 = df_r2_sec1.loc[:,'Delta_1']
r2_sec2_d1 = df_r2_sec2.loc[:,'Delta_1']
r2_sec3_d1 = df_r2_sec3.loc[:,'Delta_1']
r2_sec4_d1 = df_r2_sec4.loc[:,'Delta_1']

# %%
a = round(wt_sec1_d1.mean(),5)
b = round(wt_sec1_d1.std(),5)
c = round(r2_sec1_d1.mean(),5)
d = round(r2_sec1_d1.std(),5)
e = round(wt_sec2_d1.mean(),5)
f = round(wt_sec2_d1.std(),5)
g = round(r2_sec2_d1.mean(),5)
h = round(r2_sec2_d1.std(),5)
i = round(wt_sec3_d1.mean(),5)
j = round(wt_sec3_d1.std(),5)
k = round(r2_sec3_d1.mean(),5)
l = round(r2_sec3_d1.std(),5)
m = round(wt_sec4_d1.mean(),5)
n = round(wt_sec4_d1.std(),5)
o = round(r2_sec4_d1.mean(),5)
p = round(r2_sec4_d1.std(),5)
print("Delta Strand 1 Sections 1-4 Statistics")
print("The wt sec1 d1 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 d1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec1 d1 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r2 sec1 d1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-c,5)))

print("The wt sec2 d1 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 d1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec2 d1 mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r2 sec2 d1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(e-g,5)))

print("The wt sec3 d1 mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 d1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec3 d1 mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r2 sec3 d1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(i-k,5)))

print("The wt sec4 d1 mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 d1 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec4 d1 mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r2 sec4 d1 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(m-o,5)))
# Out:
# Delta Strand 1 Sections 1-4 Statistics
# The wt sec1 d1 mean and standard devation are 135.98312  +/-  2.5811
# The range of values within one standard deviation of the wt sec1 d1 mean are from  133.40202  to  138.56422
# The r2 sec1 d1 mean and standard devation are 136.13114  +/-  2.74875
# The range of values within one standard deviation of the r2 sec1 d1 mean are from  133.38239  to  138.87989
# The difference in mean value between wt and r2 is -0.14802
# The wt sec2 d1 mean and standard devation are 136.91502  +/-  2.82895
# The range of values within one standard deviation of the wt sec2 d1 mean are from  133.40202  to  138.56422
# The r2 sec2 d1 mean and standard devation are 133.77872  +/-  3.41941
# The range of values within one standard deviation of the r2 sec2 d1 mean are from  133.38239  to  138.87989
# The difference in mean value between wt and r2 is 3.1363
# The wt sec3 d1 mean and standard devation are 133.57133  +/-  3.10691
# ...

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_d1 = np.linspace(120, 145, 30)
ax0.hist([wt_sec1_d1, r2_sec1_d1], bins_sec_d1, label=['WT', 'Reg2'], color=['blue','orange'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Delta 1 Section 1: Wild-Type vs Region 2 Defect ')
ax0.set_xlim(120, 145)
ax0.set_ylim(0, 150)
ax1.hist([wt_sec2_d1, r2_sec2_d1], bins_sec_d1, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Delta 1 Section 2: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(120, 145)
ax1.set_ylim(0, 150)
ax2.hist([wt_sec3_d1, r2_sec3_d1], bins_sec_d1, label=['WT', 'Reg2'], color=['blue','orange'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Delta 1 Section 3: Wild-Type vs Region 2 Defect ')
ax2.set_xlim(120, 145)
ax2.set_ylim(0, 150)
ax3.hist([wt_sec4_d1, r2_sec4_d1], bins_sec_d1, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Delta 1 Section 4: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(120, 145)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
wt_sec1_d2 = df_wt_sec1.loc[:,'Delta_2']
wt_sec2_d2 = df_wt_sec2.loc[:,'Delta_2']
wt_sec3_d2 = df_wt_sec3.loc[:,'Delta_2']
wt_sec4_d2 = df_wt_sec4.loc[:,'Delta_2']
r2_sec1_d2 = df_r2_sec1.loc[:,'Delta_2']
r2_sec2_d2 = df_r2_sec2.loc[:,'Delta_2']
r2_sec3_d2 = df_r2_sec3.loc[:,'Delta_2']
r2_sec4_d2 = df_r2_sec4.loc[:,'Delta_2']

# %%
a = round(wt_sec1_d2.mean(),5)
b = round(wt_sec1_d2.std(),5)
c = round(r2_sec1_d2.mean(),5)
d = round(r2_sec1_d2.std(),5)
e = round(wt_sec2_d2.mean(),5)
f = round(wt_sec2_d2.std(),5)
g = round(r2_sec2_d2.mean(),5)
h = round(r2_sec2_d2.std(),5)
i = round(wt_sec3_d2.mean(),5)
j = round(wt_sec3_d2.std(),5)
k = round(r2_sec3_d2.mean(),5)
l = round(r2_sec3_d2.std(),5)
m = round(wt_sec4_d2.mean(),5)
n = round(wt_sec4_d2.std(),5)
o = round(r2_sec4_d2.mean(),5)
p = round(r2_sec4_d2.std(),5)
print("Delta Strand 2 Sections 1-4 Statistics")
print("The wt sec1 d2 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 d2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec1 d2 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r2 sec1 d2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-c,5)))

print("The wt sec2 d2 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 d2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec2 d2 mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r2 sec2 d2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(e-g,5)))

print("The wt sec3 d2 mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 d2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec3 d2 mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r2 sec3 d2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(i-k,5)))

print("The wt sec4 d2 mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 d2 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec4 d2 mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r2 sec4 d2 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(m-o,5)))
# Out:
# Delta Strand 2 Sections 1-4 Statistics
# The wt sec1 d2 mean and standard devation are 137.39292  +/-  2.67423
# The range of values within one standard deviation of the wt sec1 d2 mean are from  134.71869  to  140.06715
# The r2 sec1 d2 mean and standard devation are 137.06855  +/-  3.07793
# The range of values within one standard deviation of the r2 sec1 d2 mean are from  133.99062  to  140.14648
# The difference in mean value between wt and r2 is 0.32437
# The wt sec2 d2 mean and standard devation are 138.13269  +/-  2.47296
# The range of values within one standard deviation of the wt sec2 d2 mean are from  134.71869  to  140.06715
# The r2 sec2 d2 mean and standard devation are 133.51711  +/-  2.83028
# The range of values within one standard deviation of the r2 sec2 d2 mean are from  133.99062  to  140.14648
# The difference in mean value between wt and r2 is 4.61558
# The wt sec3 d2 mean and standard devation are 135.61524  +/-  3.23529
# ...

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_d2 = np.linspace(120, 145, 30)
ax0.hist([wt_sec1_d2, r2_sec1_d2], bins_sec_d2, label=['WT', 'Reg2'], color=['blue','orange'])
ax0.legend(loc='upper left')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Delta 2 Section 1: Wild-Type vs Region 2 Defect ')
ax0.set_xlim(120, 145)
ax0.set_ylim(0, 150)
ax1.hist([wt_sec2_d2, r2_sec2_d2], bins_sec_d2, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper left')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Delta 2 Section 2: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(120, 145)
ax1.set_ylim(0, 150)
ax2.hist([wt_sec3_d2, r2_sec3_d2], bins_sec_d2, label=['WT', 'Reg2'], color=['blue','orange'])
ax2.legend(loc='upper left')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Delta 2 Section 3: Wild-Type vs Region 2 Defect ')
ax2.set_xlim(120, 145)
ax2.set_ylim(0, 150)
ax3.hist([wt_sec4_d2, r2_sec4_d2], bins_sec_d2, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper left')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Delta 2 Section 4: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(120, 145)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
wt_sec1_htwi = df_wt_sec1.loc[:,'H-twi']
wt_sec2_htwi = df_wt_sec2.loc[:,'H-twi']
wt_sec3_htwi = df_wt_sec3.loc[:,'H-twi']
wt_sec4_htwi = df_wt_sec4.loc[:,'H-twi']
r2_sec1_htwi = df_r2_sec1.loc[:,'H-twi']
r2_sec2_htwi = df_r2_sec2.loc[:,'H-twi']
r2_sec3_htwi = df_r2_sec3.loc[:,'H-twi']
r2_sec4_htwi = df_r2_sec4.loc[:,'H-twi']

# %%
a = round(wt_sec1_htwi.mean(),5)
b = round(wt_sec1_htwi.std(),5)
c = round(r2_sec1_htwi.mean(),5)
d = round(r2_sec1_htwi.std(),5)
e = round(wt_sec2_htwi.mean(),5)
f = round(wt_sec2_htwi.std(),5)
g = round(r2_sec2_htwi.mean(),5)
h = round(r2_sec2_htwi.std(),5)
i = round(wt_sec3_htwi.mean(),5)
j = round(wt_sec3_htwi.std(),5)
k = round(r2_sec3_htwi.mean(),5)
l = round(r2_sec3_htwi.std(),5)
m = round(wt_sec4_htwi.mean(),5)
n = round(wt_sec4_htwi.std(),5)
o = round(r2_sec4_htwi.mean(),5)
p = round(r2_sec4_htwi.std(),5)
print("Helical Twist Sections 1-4 Statistics")
print("The wt sec1 htwi mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 htwi mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec1 htwi mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r2 sec1 htwi mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-c,5)))

print("The wt sec2 htwi mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 htwi mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec2 htwi mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r2 sec2 htwi mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(e-g,5)))

print("The wt sec3 htwi mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 htwi mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec3 htwi mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r2 sec3 htwi mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(i-k,5)))

print("The wt sec4 htwi mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 htwi mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec4 htwi mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r2 sec4 htwi mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(m-o,5)))
# Out:
# Helical Twist Sections 1-4 Statistics
# The wt sec1 htwi mean and standard devation are 35.8747  +/-  0.39909
# The range of values within one standard deviation of the wt sec1 htwi mean are from  35.47561  to  36.27379
# The r2 sec1 htwi mean and standard devation are 36.37075  +/-  0.39404
# The range of values within one standard deviation of the r2 sec1 htwi mean are from  35.97671  to  36.76479
# The difference in mean value between wt and r2 is -0.49605
# The wt sec2 htwi mean and standard devation are 35.7194  +/-  0.39787
# The range of values within one standard deviation of the wt sec2 htwi mean are from  35.47561  to  36.27379
# The r2 sec2 htwi mean and standard devation are 35.65654  +/-  0.37564
# The range of values within one standard deviation of the r2 sec2 htwi mean are from  35.97671  to  36.76479
# The difference in mean value between wt and r2 is 0.06286
# The wt sec3 htwi mean and standard devation are 35.20158  +/-  0.33475
# ...

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_htwi = np.linspace(34, 38, 30)
ax0.hist([wt_sec1_htwi, r2_sec1_htwi], bins_sec_htwi, label=['WT', 'Reg2'], color=['blue','orange'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($^\circ$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Helical Twist Section 1: Wild-Type vs Region 2 Defect ')
ax0.set_xlim(34, 38)
ax0.set_ylim(0, 190)
ax1.hist([wt_sec2_htwi, r2_sec2_htwi], bins_sec_htwi, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Helical Twist Section 2: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(34, 38)
ax1.set_ylim(0, 190)
ax2.hist([wt_sec3_htwi, r2_sec3_htwi], bins_sec_htwi, label=['WT', 'Reg2'], color=['blue','orange'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($^\circ$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Helical Twist Section 3: Wild-Type vs Region 2 Defect ')
ax2.set_xlim(34, 38)
ax2.set_ylim(0, 190)
ax3.hist([wt_sec4_htwi, r2_sec4_htwi], bins_sec_htwi, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($^\circ$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Helical Twist Section 4: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(34, 38)
ax3.set_ylim(0, 190)
fig.tight_layout()

# %%
wt_sec1_w12 = df_wt_sec1.loc[:,'W12']
wt_sec2_w12 = df_wt_sec2.loc[:,'W12']
wt_sec3_w12 = df_wt_sec3.loc[:,'W12']
wt_sec4_w12 = df_wt_sec4.loc[:,'W12']
r2_sec1_w12 = df_r2_sec1.loc[:,'W12']
r2_sec2_w12 = df_r2_sec2.loc[:,'W12']
r2_sec3_w12 = df_r2_sec3.loc[:,'W12']
r2_sec4_w12 = df_r2_sec4.loc[:,'W12']

# %%
a = round(wt_sec1_w12.mean(),5)
b = round(wt_sec1_w12.std(),5)
c = round(r2_sec1_w12.mean(),5)
d = round(r2_sec1_w12.std(),5)
e = round(wt_sec2_w12.mean(),5)
f = round(wt_sec2_w12.std(),5)
g = round(r2_sec2_w12.mean(),5)
h = round(r2_sec2_w12.std(),5)
i = round(wt_sec3_w12.mean(),5)
j = round(wt_sec3_w12.std(),5)
k = round(r2_sec3_w12.mean(),5)
l = round(r2_sec3_w12.std(),5)
m = round(wt_sec4_w12.mean(),5)
n = round(wt_sec4_w12.std(),5)
o = round(r2_sec4_w12.mean(),5)
p = round(r2_sec4_w12.std(),5)
print("Minor Width Sections 1-4 Statistics")
print("The wt sec1 w12 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 w12 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec1 w12 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r2 sec1 w12 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-c,5)))

print("The wt sec2 w12 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 w12 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec2 w12 mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r2 sec2 w12 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(e-g,5)))

print("The wt sec3 w12 mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 w12 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec3 w12 mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r2 sec3 w12 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(i-k,5)))

print("The wt sec4 w12 mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 w12 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec4 w12 mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r2 sec4 w12 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(m-o,5)))
# Out:
# Minor Width Sections 1-4 Statistics
# The wt sec1 w12 mean and standard devation are 5.05604  +/-  0.26267
# The range of values within one standard deviation of the wt sec1 w12 mean are from  4.79337  to  5.31871
# The r2 sec1 w12 mean and standard devation are 5.12142  +/-  0.26944
# The range of values within one standard deviation of the r2 sec1 w12 mean are from  4.85198  to  5.39086
# The difference in mean value between wt and r2 is -0.06538
# The wt sec2 w12 mean and standard devation are 4.80845  +/-  0.25165
# The range of values within one standard deviation of the wt sec2 w12 mean are from  4.79337  to  5.31871
# The r2 sec2 w12 mean and standard devation are 5.13978  +/-  0.27827
# The range of values within one standard deviation of the r2 sec2 w12 mean are from  4.85198  to  5.39086
# The difference in mean value between wt and r2 is -0.33133
# The wt sec3 w12 mean and standard devation are 5.07234  +/-  0.27211
# ...

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_w12 = np.linspace(4, 6.5, 30)
ax0.hist([wt_sec1_w12, r2_sec1_w12], bins_sec_w12, label=['WT', 'Reg2'], color=['blue','orange'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Minor Width Section 1: Wild-Type vs Region 2 Defect ')
ax0.set_xlim(4, 6.5)
ax0.set_ylim(0, 160)
ax1.hist([wt_sec2_w12, r2_sec2_w12], bins_sec_w12, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Minor Width Section 2: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(4, 6.5)
ax1.set_ylim(0, 160)
ax2.hist([wt_sec3_w12, r2_sec3_w12], bins_sec_w12, label=['WT', 'Reg2'], color=['blue','orange'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Minor Width Section 3: Wild-Type vs Region 2 Defect ')
ax2.set_xlim(4, 6.5)
ax2.set_ylim(0, 160)
ax3.hist([wt_sec4_w12, r2_sec4_w12], bins_sec_w12, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Minor Width Section 4: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(4, 6.5)
ax3.set_ylim(0, 160)
fig.tight_layout()

# %%
df_r1_sec1 = pd.read_csv('./8oxoG_0_reg1_weka_inputs/sec2_8oxoG_0_reg1_weka_input.csv')
df_r1_sec2 = pd.read_csv('./8oxoG_0_reg1_weka_inputs/sec3_8oxoG_0_reg1_weka_input.csv')
df_r1_sec3 = pd.read_csv('./8oxoG_0_reg1_weka_inputs/sec4_8oxoG_0_reg1_weka_input.csv')
df_r1_sec4 = pd.read_csv('./8oxoG_0_reg1_weka_inputs/sec5_8oxoG_0_reg1_weka_input.csv')
wt_sec1_d21 = df_wt_sec1.loc[:,'D21']
wt_sec2_d21 = df_wt_sec2.loc[:,'D21']
wt_sec3_d21 = df_wt_sec3.loc[:,'D21']
wt_sec4_d21 = df_wt_sec4.loc[:,'D21']
wt_sec1_w21 = df_wt_sec1.loc[:,'W21']
wt_sec2_w21 = df_wt_sec2.loc[:,'W21']
wt_sec3_w21 = df_wt_sec3.loc[:,'W21']
wt_sec4_w21 = df_wt_sec4.loc[:,'W21']
r1_sec1_d21 = df_r1_sec1.loc[:,'D21']
r1_sec2_d21 = df_r1_sec2.loc[:,'D21']
r1_sec3_d21 = df_r1_sec3.loc[:,'D21']
r1_sec4_d21 = df_r1_sec4.loc[:,'D21']
r1_sec1_w21 = df_r1_sec1.loc[:,'W21']
r1_sec2_w21 = df_r1_sec2.loc[:,'W21']
r1_sec3_w21 = df_r1_sec3.loc[:,'W21']
r1_sec4_w21 = df_r1_sec4.loc[:,'W21']
r2_sec1_d21 = df_r2_sec1.loc[:,'D21']
r2_sec2_d21 = df_r2_sec2.loc[:,'D21']
r2_sec3_d21 = df_r2_sec3.loc[:,'D21']
r2_sec4_d21 = df_r2_sec4.loc[:,'D21']

# %%
a = round(wt_sec1_w21.mean(),5)
b = round(wt_sec1_w21.std(),5)
c = round(r1_sec1_w21.mean(),5)
d = round(r1_sec1_w21.std(),5)
e = round(wt_sec2_w21.mean(),5)
f = round(wt_sec2_w21.std(),5)
g = round(r1_sec2_w21.mean(),5)
h = round(r1_sec2_w21.std(),5)
i = round(wt_sec3_w21.mean(),5)
j = round(wt_sec3_w21.std(),5)
k = round(r1_sec3_w21.mean(),5)
l = round(r1_sec3_w21.std(),5)
m = round(wt_sec4_w21.mean(),5)
n = round(wt_sec4_w21.std(),5)
o = round(r1_sec4_w21.mean(),5)
p = round(r1_sec4_w21.std(),5)
print("Major Width Sections 1-4 Statistics")
print("The wt sec1 w21 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 w21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 sec1 w21 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 sec1 w21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))

print("The wt sec2 w21 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 w21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 sec2 w21 mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r1 sec2 w21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(e-g,5)))

print("The wt sec3 w21 mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 w21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 sec3 w21 mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r1 sec3 w21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(i-k,5)))

print("The wt sec4 w21 mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 w21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 sec4 w21 mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r1 sec4 w21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(m-o,5)))
# Out:
# Major Width Sections 1-4 Statistics
# The wt sec1 w21 mean and standard devation are 11.103  +/-  0.29888
# The range of values within one standard deviation of the wt sec1 w21 mean are from  10.80412  to  11.40188
# The r1 sec1 w21 mean and standard devation are 11.28156  +/-  0.2991
# The range of values within one standard deviation of the r1 sec1 w21 mean are from  10.98246  to  11.58066
# The difference in mean value between wt and r1 is -0.17856
# The wt sec2 w21 mean and standard devation are 11.42315  +/-  0.27146
# The range of values within one standard deviation of the wt sec2 w21 mean are from  10.80412  to  11.40188
# The r1 sec2 w21 mean and standard devation are 11.48157  +/-  0.28506
# The range of values within one standard deviation of the r1 sec2 w21 mean are from  10.98246  to  11.58066
# The difference in mean value between wt and r1 is -0.05842
# The wt sec3 w21 mean and standard devation are 11.45802  +/-  0.29859
# ...

# %%
a = round(wt_sec1_d21.mean(),5)
b = round(wt_sec1_d21.std(),5)
c = round(r1_sec1_d21.mean(),5)
d = round(r1_sec1_d21.std(),5)
e = round(wt_sec2_d21.mean(),5)
f = round(wt_sec2_d21.std(),5)
g = round(r1_sec2_d21.mean(),5)
h = round(r1_sec2_d21.std(),5)
i = round(wt_sec3_d21.mean(),5)
j = round(wt_sec3_d21.std(),5)
k = round(r1_sec3_d21.mean(),5)
l = round(r1_sec3_d21.std(),5)
m = round(wt_sec4_d21.mean(),5)
n = round(wt_sec4_d21.std(),5)
o = round(r1_sec4_d21.mean(),5)
p = round(r1_sec4_d21.std(),5)
print("Major Depth Sections 1-4 Statistics")
print("The wt sec1 d21 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 d21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 sec1 d21 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r1 sec1 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(a-c,5)))

print("The wt sec2 d21 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 d21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 sec2 d21 mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r1 sec2 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(e-g,5)))

print("The wt sec3 d21 mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 d21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 sec3 d21 mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r1 sec3 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(i-k,5)))

print("The wt sec4 d21 mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 d21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r1 sec4 d21 mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r1 sec4 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r1 is " + str(round(m-o,5)))
# Out:
# Major Depth Sections 1-4 Statistics
# The wt sec1 d21 mean and standard devation are 4.572  +/-  0.2894
# The range of values within one standard deviation of the wt sec1 d21 mean are from  4.2826  to  4.8614
# The r1 sec1 d21 mean and standard devation are 4.33441  +/-  0.28759
# The range of values within one standard deviation of the r1 sec1 d21 mean are from  4.04682  to  4.622
# The difference in mean value between wt and r1 is 0.23759
# The wt sec2 d21 mean and standard devation are 4.54507  +/-  0.31125
# The range of values within one standard deviation of the wt sec2 d21 mean are from  4.2826  to  4.8614
# The r1 sec2 d21 mean and standard devation are 4.48947  +/-  0.31877
# The range of values within one standard deviation of the r1 sec2 d21 mean are from  4.04682  to  4.622
# The difference in mean value between wt and r1 is 0.0556
# The wt sec3 d21 mean and standard devation are 4.74102  +/-  0.28295
# ...

# %%
a = round(wt_sec1_d21.mean(),5)
b = round(wt_sec1_d21.std(),5)
c = round(r2_sec1_d21.mean(),5)
d = round(r2_sec1_d21.std(),5)
e = round(wt_sec2_d21.mean(),5)
f = round(wt_sec2_d21.std(),5)
g = round(r2_sec2_d21.mean(),5)
h = round(r2_sec2_d21.std(),5)
i = round(wt_sec3_d21.mean(),5)
j = round(wt_sec3_d21.std(),5)
k = round(r2_sec3_d21.mean(),5)
l = round(r2_sec3_d21.std(),5)
m = round(wt_sec4_d21.mean(),5)
n = round(wt_sec4_d21.std(),5)
o = round(r2_sec4_d21.mean(),5)
p = round(r2_sec4_d21.std(),5)
print("Major Depth Sections 1-4 Statistics")
print("The wt sec1 d21 mean and standard devation are " + str(a) + "  +/-  " + str(b))
print("The range of values within one standard deviation of the wt sec1 d21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec1 d21 mean and standard devation are " + str(c) + "  +/-  " + str(d))
print("The range of values within one standard deviation of the r2 sec1 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(a-c,5)))

print("The wt sec2 d21 mean and standard devation are " + str(e) + "  +/-  " + str(f))
print("The range of values within one standard deviation of the wt sec2 d21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec2 d21 mean and standard devation are " + str(g) + "  +/-  " + str(h))
print("The range of values within one standard deviation of the r2 sec2 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(e-g,5)))

print("The wt sec3 d21 mean and standard devation are " + str(i) + "  +/-  " + str(j))
print("The range of values within one standard deviation of the wt sec3 d21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec3 d21 mean and standard devation are " + str(k) + "  +/-  " + str(l))
print("The range of values within one standard deviation of the r2 sec3 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(i-k,5)))

print("The wt sec4 d21 mean and standard devation are " + str(m) + "  +/-  " + str(n))
print("The range of values within one standard deviation of the wt sec4 d21 mean are from  " + str(round(a-b,5)) + "  to  " + str(round(a+b,5)))

print("The r2 sec4 d21 mean and standard devation are " + str(o) + "  +/-  " + str(p))
print("The range of values within one standard deviation of the r2 sec4 d21 mean are from  " + str(round(c-d,5)) + "  to  " + str(round(c+d,5)))
print("The difference in mean value between wt and r2 is " + str(round(m-o,5)))
# Out:
# Major Depth Sections 1-4 Statistics
# The wt sec1 d21 mean and standard devation are 4.572  +/-  0.2894
# The range of values within one standard deviation of the wt sec1 d21 mean are from  4.2826  to  4.8614
# The r2 sec1 d21 mean and standard devation are 4.50052  +/-  0.26997
# The range of values within one standard deviation of the r2 sec1 d21 mean are from  4.23055  to  4.77049
# The difference in mean value between wt and r2 is 0.07148
# The wt sec2 d21 mean and standard devation are 4.54507  +/-  0.31125
# The range of values within one standard deviation of the wt sec2 d21 mean are from  4.2826  to  4.8614
# The r2 sec2 d21 mean and standard devation are 4.70175  +/-  0.30863
# The range of values within one standard deviation of the r2 sec2 d21 mean are from  4.23055  to  4.77049
# The difference in mean value between wt and r2 is -0.15668
# The wt sec3 d21 mean and standard devation are 4.74102  +/-  0.28295
# ...

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_w12 = np.linspace(10, 13, 30)
ax0.hist([wt_sec1_w21, r1_sec1_w21], bins_sec_w12, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Major Width Section 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(10, 13)
ax0.set_ylim(0, 180)
ax1.hist([wt_sec2_w21, r1_sec2_w21], bins_sec_w12, label=['WT', 'Reg1'], color=['blue','red'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Major Width Section 2: Wild-Type vs Region 1 Defect ')
ax1.set_xlim(10, 13)
ax1.set_ylim(0, 180)
ax2.hist([wt_sec3_w21, r1_sec3_w21], bins_sec_w12, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Major Width Section 3: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(10,13)
ax2.set_ylim(0, 180)
ax3.hist([wt_sec4_w21, r1_sec4_w21], bins_sec_w12, label=['WT', 'Reg1'], color=['blue','red'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Major Width Section 4: Wild-Type vs Region 1 Defect ')
ax3.set_xlim(10,13)
ax3.set_ylim(0, 180)
fig.tight_layout()

# %%
plt.rcParams.update({'font.size': 12})
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_d21 = np.linspace(3.5, 6, 30)
ax0.hist([wt_sec1_d21, r1_sec1_d21], bins_sec_d21, label=['WT', 'Reg1'], color=['blue','red'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Major Depth Section 1: Wild-Type vs Region 1 Defect ')
ax0.set_xlim(3.5, 6)
ax0.set_ylim(0, 150)
ax1.hist([wt_sec2_d21, r1_sec2_d21], bins_sec_d21, label=['WT', 'Reg1'], color=['blue','red'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Major Depth Section 2: Wild-Type vs Region 1 Defect ')
ax1.set_xlim(3.5, 6)
ax1.set_ylim(0, 150)
ax2.hist([wt_sec3_d21, r1_sec3_d21], bins_sec_d21, label=['WT', 'Reg1'], color=['blue','red'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Major Depth Section 3: Wild-Type vs Region 1 Defect ')
ax2.set_xlim(3.5,6)
ax2.set_ylim(0, 150)
ax3.hist([wt_sec4_d21, r1_sec4_d21], bins_sec_d21, label=['WT', 'Reg1'], color=['blue','red'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Major Depth Section 4: Wild-Type vs Region 1 Defect ')
ax3.set_xlim(3.5,6)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
bins_sec_d21 = np.linspace(3.5, 6, 30)
ax0.hist([wt_sec1_d21, r2_sec1_d21], bins_sec_d21, label=['WT', 'Reg2'], color=['blue','orange'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Major Depth Section 1: Wild-Type vs Region 2 Defect ')
ax0.set_xlim(3.5, 6)
ax0.set_ylim(0, 150)
ax1.hist([wt_sec2_d21, r2_sec2_d21], bins_sec_d21, label=['WT', 'Reg2'], color=['blue','orange'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Major Depth Section 2: Wild-Type vs Region 2 Defect ')
ax1.set_xlim(3.5, 6)
ax1.set_ylim(0, 150)
ax2.hist([wt_sec3_d21, r2_sec3_d21], bins_sec_d21, label=['WT', 'Reg2'], color=['blue','orange'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Major Depth Section 3: Wild-Type vs Region 2 Defect ')
ax2.set_xlim(3.5,6)
ax2.set_ylim(0, 150)
ax3.hist([wt_sec4_d21, r2_sec4_d21], bins_sec_d21, label=['WT', 'Reg2'], color=['blue','orange'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Major Depth Section 4: Wild-Type vs Region 2 Defect ')
ax3.set_xlim(3.5,6)
ax3.set_ylim(0, 150)
fig.tight_layout()

# %%
df_wt_all_146 = pd.read_csv('./wt_0_weka_inputs/wt_0_all_weka_input.csv')
wt_all_stretch = df_wt_all_146.loc[:,'Stretch']
fig, ((ax0)) = plt.subplots(nrows=1, ncols=1, figsize=(5,3))
ax0.hist([wt_all_stretch, wt_notails_stretch], 30, label=['Full', 'No Tails'], color=['green','blue'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Stretch: Full NCP vs No Tails NCP ')
ax0.set_xlim(-0.1, 0.08)
ax0.set_ylim(0, 200)
fig.tight_layout()

# %%
#plt.rcParams["font.family"] = "Arial"
#plt.rcParams["legend.labelcolor"] = "#413D3A"
#plt.rcParams["legend.edgecolor"] = "#413D3A"  
#plt.rcParams.update({'font.size': 14})
fig, (ax0) = plt.subplots(nrows=1, ncols=1, figsize=(10,6))
bins_tails_stretch = np.linspace(-0.08, 0.08, 40)
ax0.hist([wt_all_stretch, wt_notails_stretch, r2_notails_stretch], bins_tails_stretch, label=['WT Full', 'WT No DNA Tails', '8oxoG No DNA Tails'], color=[ '#413D3A','#007480','#B51F1F'])
ax0.legend(loc='upper left')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Stretch: Wild-Type Full vs Wild-Type No DNA Tails vs 8oxoG Defect No DNA Tails')
ax0.set_xlim(-0.08, 0.08)
ax0.set_ylim(0, 130)
ax0.spines['bottom'].set_color('#413D3A')
ax0.spines['top'].set_color('#413D3A') 
ax0.spines['right'].set_color('#413D3A')
ax0.spines['left'].set_color('#413D3A')
ax0.tick_params(axis='x', colors='#413D3A')
ax0.tick_params(axis='y', colors='#413D3A')
ax0.yaxis.label.set_color('#413D3A')
ax0.xaxis.label.set_color('#413D3A')
ax0.title.set_color('#413D3A')
bins_stretch = np.linspace(-0.025, 0.08, 30)
ax1.hist([wt_notails_stretch, r2_notails_stretch], bins_stretch, label=['WT No DNA Tails', '8oxoG No DNA Tails'], color=['#413D3A','#B51F1F'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($\AA$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Stretch: Wild-Type versus Defect ')
ax1.set_xlim(-0.025, 0.08)
ax1.set_ylim(0, 200)
ax1.spines['bottom'].set_color('#413D3A')
ax1.spines['top'].set_color('#413D3A') 
ax1.spines['right'].set_color('#413D3A')
ax1.spines['left'].set_color('#413D3A')
ax1.tick_params(axis='x', colors='#413D3A')
ax1.tick_params(axis='y', colors='#413D3A')
ax1.yaxis.label.set_color('#413D3A')
ax1.xaxis.label.set_color('#413D3A')
ax1.title.set_color('#413D3A')
fig.tight_layout()
plt.savefig('../poster_three.png', transparent=True)

# %%
plt.rcParams["font.family"] = "Arial"
plt.rcParams["legend.labelcolor"] = "#413D3A"
plt.rcParams["legend.edgecolor"] = "#413D3A"  
plt.rcParams.update({'font.size': 14})
fig, ((ax0, ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
ax0.hist([wt_notails_hris, r2_notails_hris], bins_hrise, label=['WT', '8oxoG'], color=['#413D3A','#B51F1F'])
ax0.legend(loc='upper right')
ax0.set_xlabel('Value ($\AA$)')
ax0.set_ylabel('Frame Count')
ax0.set_title('Helical Rise: Wild-Type vs 8oxoG')
ax0.set_xlim(3.25, 3.45)
ax0.set_ylim(0, 160)
ax1.hist([wt_notails_a2, r2_notails_a2], bins_a, label=['WT', '8oxoG'], color=['#413D3A','#B51F1F'])
ax1.legend(loc='upper right')
ax1.set_xlabel('Value ($^\circ$)')
ax1.set_ylabel('Frame Count')
ax1.set_title('Alpha Dihedral: Wild-Type vs 8oxoG ')
ax1.set_xlim(-80, -60)
ax1.set_ylim(0, 160)
ax2.hist([wt_notails_w21, r2_notails_w21], bins_w21, label=['WT', '8oxoG'], color=['#413D3A','#B51F1F'])
ax2.legend(loc='upper right')
ax2.set_xlabel('Value ($\AA$)')
ax2.set_ylabel('Frame Count')
ax2.set_title('Major Groove Width: Wild-Type vs 8oxoG ')
ax2.set_xlim(10.9, 12.1)
ax2.set_ylim(0, 160)
ax3.hist([wt_notails_d21, r2_notails_d21], bins_d21, label=['WT', '8oxoG'], color=['#413D3A','#B51F1F'])
ax3.legend(loc='upper right')
ax3.set_xlabel('Value ($\AA$)')
ax3.set_ylabel('Frame Count')
ax3.set_title('Major Groove Depth: Wild-Type vs 8oxoG ')
ax3.set_xlim(4.3, 5.3)
ax3.set_ylim(0, 120)
fig.tight_layout()
plt.savefig('../poster_four.png', transparent=True)

# %%
np.random.seed(19680801)

n_bins = 10
x = np.random.randn(1000, 3)

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2)

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()
